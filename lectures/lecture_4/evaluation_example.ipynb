# %% [markdown]
# # Критерии оценки ДЗ
#
# > **Версия LanceDB: `lancedb<0.20` !!!**
#
# Делаете прогоны на test_dataset, выбиваете максимум по метрикам. Я буду проверять на eval_dataset
#
# ---
#
# ## Базовые требования (4 балла)
#
# | # | Критерий | Баллы |
# |---|----------|-------|
# | 1 | Описан процесс подготовки данных (`data_preporation.py`, `embedder.py`) | 1 |
# | 2 | Описаны методы/функции для работы с векторной БД в `lance_db.py` (обязательно `read_all`) | 1 |
# | 3 | Данные записаны в БД и можно выполнить `read_all` | 1 |
# | 4 | Описан флоу retrieve и agent (`agent.py`, `retriever.py`) | 1 |
#
# ---
#
# ## Метрики качества (до 9 баллов)
#
# ### F1@K
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.50   | 1     |
# | > 0.75   | 2     |
# | > 0.90   | 3     |
#
# ### NDCG@K
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.65   | 1     |
# | > 0.75   | 2     |
# | > 0.90   | 3     |
#
# ### Faithfulness
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.75   | 1     |
# | > 0.85   | 2     |
# | > 0.95   | 3     |
#
# ---
#
# ## Лог эволюции (до 2 баллов)
#
# Оценивается индивидуально на основании полноты информации в `EVOLUTION.md`.
#
# ---
#
# ## Штрафы
#
# | Условие | Штраф |
# |---------|-------|
# | Суммарный объём всех передаваемых для генерации чанков > 6000 символов | −100500 баллов |
# | Использовали дополнительные библиотеки и не положили requirements.txt | −100500 баллов |
#
# ---
#
# **Максимум: 15 баллов** (4 базовых + 9 метрики + 2 эволюция)

# %% [markdown]
# # Валидация RAG-агента через модуль `evaluation.py`
#
# Демонстрация полного пайплайна оценки:
# 1. Подключаемся к векторному хранилищу и создаём агента
# 2. Загружаем тестовый датасет
# 3. Прогоняем агента на всех вопросах (многопоточно)
# 4. Вызываем `evaluate()` — получаем DataFrame с 7 метриками
# 5. Анализируем результаты

# %% [markdown]
# ---
# ## 0. Подготовка

# %%
import warnings

warnings.filterwarnings("ignore")

import sys
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm


def _find_project_root(start: Path) -> Path:
    for p in (start, *start.parents):
        if (p / "pyproject.toml").exists():
            return p
    return start


PROJECT_ROOT = _find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import settings
from openai import OpenAI

# %%
client = OpenAI(
    base_url="https://api.polza.ai/api/v1",
    api_key=settings.polza_ai_api_key,
)

MODEL = "openai/gpt-4o-mini"

# %%
# 1
from data_preporation import build_vectorstore

table = build_vectorstore(
    client=client,
    chunk_size=1500,
    chunk_overlap=400,
)

# %% [markdown]
# ---
# ## 1. Подключаемся к векторному хранилищу и создаём агента

# %%
import lancedb

VECTORSTORE_DIR = "lance_db/vectorstore"
TABLE_NAME = "chunks"

db = lancedb.connect(VECTORSTORE_DIR)
table = db.open_table(TABLE_NAME)

print(f"\u2705 Таблица '{TABLE_NAME}' открыта: {table.count_rows()} строк")
# Out:
# ✅ Таблица 'chunks' открыта: 47 строк

# %%
from agent import RAGAgent, RAGAgentAnswer, TOOLS_SCHEMA, get_tool_functions

TOOL_FUNCTIONS = get_tool_functions(table, client)

agent = RAGAgent(
    client=client,
    model=MODEL,
    tools_schema=TOOLS_SCHEMA,
    tool_functions=TOOL_FUNCTIONS,
)

print("\u2705 Агент готов")
# Out:
# ✅ Агент готов

# %% [markdown]
# ---
# ## 2. Загрузка тестового датасета
#
# Датасет: `data/test_dataframe.xlsx` — 150 вопросов с ground truth.
#
# | Колонка | Описание |
# |---------|----------|
# | `id` | Уникальный идентификатор вопроса |
# | `question` | Вопрос на естественном языке |
# | `ground_truth_chunks` | Эталонные чанки (строковое представление списка) |
# | `document` | Год отчёта (2019 / 2025) |

# %%
df_test = pd.read_excel("dataset/test_dataframe.xlsx")
print(f"Размер: {df_test.shape}")
print(f"Колонки: {list(df_test.columns)}")
# df_test = df_test.head(20)
df_test.head(3)
# Out:
# Размер: (150, 4)
# Колонки: ['id', 'question', 'relevant_text', 'document']
#                                      id  \
# 0  e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1  c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2  7e727f79-c6ff-4ff0-b101-bcec2b0f7260
#
#                                             question  \
# 0  В 2019 году как изменился индекс потребительск...
# 1  Согласно данным 2025 года, какой фактор являет...
# 2  Согласно данным 2019 года, что является основн...
#
#                                        relevant_text  document
# 0  ['Как мы предполагали при анализе результатов ...      2019
# 1  ['Одним из главных негативных факторов, тормоз...      2025
# 2  ['Очевидно, что основным фактором, определяющи...      2019

# %% [markdown]
# ---
# ## 3. Прогон агента на тестовом датасете
#
# Запускаем агента на каждом вопросе и сохраняем `list[RAGAgentAnswer]`.
# Это **дорогая операция** (150 вопросов × N API-вызовов), поэтому используем многопоточность.

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed


def _run_single(idx: int, row_id: str, question: str, agent: RAGAgent) -> tuple[int, RAGAgentAnswer]:
    """Один вызов агента (для параллельного запуска)."""
    try:
        result = agent.run(question, verbose=False, dataset_row_id=row_id)
    except Exception as e:
        print(f"  [Ошибка] вопрос {idx}: {e}")
        result = RAGAgentAnswer(dataset_row_id=row_id, answer=f"[Ошибка: {e}]", retrieved_chunks=None)
    return idx, result


def run_evaluation(df: pd.DataFrame, agent: RAGAgent, max_workers: int = 4) -> list[RAGAgentAnswer]:
    """Прогнать агента на всех вопросах (многопоточно)."""
    results: list[RAGAgentAnswer | None] = [None] * len(df)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(_run_single, idx, row["id"], row["question"], agent): idx for idx, row in df.iterrows()
        }
        for future in tqdm(as_completed(futures), total=len(futures), desc="Прогон агента"):
            idx, result = future.result()
            results[idx] = result

    return results

# %%
results = run_evaluation(df_test, agent)

print(f"\nВсего результатов: {len(results)}")
print(f"С чанками: {sum(1 for r in results if r.retrieved_chunks)}")
print(f"Без чанков (None): {sum(1 for r in results if not r.retrieved_chunks)}")
# Out:
# Прогон агента: 100%|██████████| 150/150 [01:55<00:00,  1.30it/s]
# Всего результатов: 150
# С чанками: 150
# Без чанков (None): 0

# %% [markdown]
# ---
# ## 4. Оценка через `evaluation.evaluate()`
#
# Весь расчёт метрик — **одна строка**. Модуль `evaluation.py` принимает:
# - `answers`: `list[RAGAgentAnswer]` — ответы агента
# - `dataset`: `pd.DataFrame` — тестовый датасет с ground truth
# - `client` + `model` — для вычисления Faithfulness (LLM-as-judge)
#
# Возвращает `pd.DataFrame` с метриками по каждому вопросу.

# %%
df_test
# Out:
#                                        id  \
# 0    e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1    c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2    7e727f79-c6ff-4ff0-b101-bcec2b0f7260
# 3    d52e6df3-d5ad-404e-9da9-f6f1855d16df
# 4    536bf426-d85f-472c-b434-6796078cf647
# ..                                    ...
# 145  17fc34cc-b8eb-49f0-b384-1d1db1998846
# 146  60a79f64-8f20-44dc-955e-8e8deee332e8
# 147  f5995543-80ec-4eb6-a0e2-fdf0b5d0de05
# 148  635706a4-8be4-4550-9782-02bbaf29e2cd
# 149  0ea06009-054d-427e-bd67-40579b294330
#
#                                               question  \
# 0    В 2019 году как изменился индекс потребительск...
# 1    Согласно данным 2025 года, какой фактор являет...
# 2    Согласно данным 2019 года, что является основн...
# 3    Какой процент респондентов в 2025 году затрудн...
# 4    Согласно данным 2019 года, какой был баланс от...
# ..                                                 ...
# 145  Согласно данным 2025 года, какой процент респо...
# 146  обобщающий индекс потребительской уверенности ...
# 147  В 2025 году что является важнейшим конъюнктурн...
# 148  Как изменилось восприятие респондентов относит...
# 149  В 2025 году какая часть населения сталкивается...
#
#                                          relevant_text  document
# 0    ['Как мы предполагали при анализе результатов ...      2019
# 1    ['Одним из главных негативных факторов, тормоз...      2025
# 2    ['Очевидно, что основным фактором, определяющи...      2019
# 3                      ['затрудняюсь ответить — 0,6%']      2025
# 4    ['В результате, баланс отрицательных и положит...      2019
# ..                                                 ...       ...
# 145                  ['- затрудняюсь ответить — 0,3%']      2025
# 146  ['Обобщающий индекс потребительской уверенност...      2025
# 147  ['Именно ожидания людей и бизнеса являются важ...      2025
# 148  ['аспределение мнений респондентов сместилось ...      2019
# 149  ['на людей, не имеющих возможности в достаточн...      2025
#
# [150 rows x 4 columns]

# %%
results
# Out:
# [RAGAgentAnswer(dataset_row_id='e876ec3b-7442-4145-99d0-d6bb85fd982d', answer='В 2019 году индекс потребительской уверенности повысился на 1 процентный пункт по сравнению с предыдущим годом и составил -15%.', retrieved_chunks=[Chunk(text='. Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны. Основные итоги II квартала 2019 года − Индекс потребительской уверенности (ИПУ) повысился на 1 процентный пункт (п. п.) до значения ( -15)% − Улучшени е личного материального положения за последние 12 месяцев констатировали 11% респондентов, а его ухудшени е – 32% (кварталом ранее – 10 и 34%) − Ухудшения личного материального положения в течение следующих 12 месяцев ожидают 19% респондентов (кварталом ранее - 23%) − Позитивно оценили произошедшие за год изменения в экономике России 12% участников опроса, негативно – 42% (кварталом ранее – 11 и 45%) − Положительных изменений в экономике России через год ожидают 15% опрошенных, отрицательных – 29% (кварталом ранее – 16 и 33%) Во II квартале 2019 г. продолжилось постепенн ое восстановление совокупны х потребительских настроений российского населения после их резкого ухудшения в конце предыдущего года. И ндекс потребительской уверенности (ИПУ) вновь вырос на 1 п. п. относительно параметров предыдущего квартала и достиг отметки (- 15%), что практически соответствует среднему долговременному уровню данного индикатора за всю двадцатилетнюю историю его расчета. Индекс потребительской уверенности Рис. 1', chunk_id='Potrebitelskie_ozhidaniya_2_2019:3', year=2019, distance=0.5712268948554993), Chunk(text='Потребительские настроения населения во II квартале 2019 года 3 Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно -аналитический материал о потребительских настроениях населения России
полагали при анализе результатов предыдущего раунда обследования, позитивная коррекция индекса потребительской уверенности, начавшаяся в I квартале 2019 г., продолжилась во II квартале. Правда, темпы улучшения показателя остались минимальными (по 1 п. п', chunk_id='Potrebitelskie_ozhidaniya_2_2019:11', year=2019, distance=0.5428187251091003), Chunk(text='Потребительские настроения населения во II квартале 2019 года 3 Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно -аналитический материал о потребительских настроениях населения России в о II квартале 2019 г. В обзоре использованы итоги опросов по требителей, в которых принимают участие более 5 тыс. человек в возрасте от 16 лет и старше, проживающих в частных домохозяйствах . Опросы проводятся Федеральной службой государственной статистики в ежеквартальном режиме во всех субъектах Российской Федерации . Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние ...
#  RAGAgentAnswer(dataset_row_id='d52e6df3-d5ad-404e-9da9-f6f1855d16df', answer='В 2025 году 0,3% респондентов затруднились дать ответ на вопрос о своём финансовом состоянии.', retrieved_chunks=[Chunk(text='10 Рис. 5. Ðàñïðåäåëåíèå ìíåíèé ðåñïîíäåíòîâ îá óñëîâèÿõ äëÿ êðóïíûõ ïîêóïîê Доля от общего числа респондентов, % Рис. 6. Ðàñïðåäåëåíèå ìíåíèé ðåñïîíäåíòîâ îá îæèäàåìûõ èçìåíåíèÿõ öåí Доля от общего числа респондентов, % 0,7 11,6 45,6 29,4 12,5 0,3 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить 0,3 1,9 11,6 39,0 47,0 0,2 значительно снизятся незначительно снизятся останутся на прежнем уровне незначительно возрастут значительно возрастут затрудняюсь ответить', chunk_id='Consumer_sentiment_2Q2025:22', year=2025, distance=0.8983268141746521), Chunk(text='. Значит за год произошло некоторое ухудшение состояния важнейшего социального индикатора – «неравенство в доходах». Однако следует обратить внимание, что зафиксированн ое Росстатом в I кв. значение коэффициента Джини (0,402) находится по международн ой классификации на нижней границе нейтрального уровня и не является слишком высоким. Так, по оценочной методологии Всемирного банка, при страновых сравнениях принято считать значение коэффициента Джини (распределение по кривой Лоренца) от 0,0 до 0,350, как благоприятный уровень, от 0,351 до 0,500, как нейтральный и от 0,501 до 1,0, как небла гоприятный. Российский коэффициент Джини смотрится лучше, чем, например, в США и Китае , но уступает практически всем европейским странам. Одним из главных негативных факторов, тормозящих ро ст благосостояния населения, является рост цен на товары и услуги (инфляция). Так, исходя из обобщённых мнений респондентов, в от чётном квартале лишь 2,2% из них надеются на снижение цен в течении ближайшего г ода (0,3% - значительного и 1,9 – незначительного). Об ожидаемом росте цен в своих от ветах констатировала подавляющая доля участников опроса (86%). Чуть более 10% респондентов (11,8%) надеются на сохранение текущих цен на товары и услуги в интервале ближайшего года. 1,3 12,8 42,8 29 13,5 0,6 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить', chunk_id='Consumer_sentiment_2Q2025:24', year=2025, distance=0.901654064655304), Chunk(text='9 Ðàñïðåäåëåíèå îòâåòîâ íà îòäåëüíûå âîïðîñû àíêåòû Анализ распределения мнений респондентов относитель но отдельных показателей, формирующих потребительскую уверенность населения и представленных в пятикатегорийном интервале (от «очень хорошее» до « очень плохое»), показывает, хотя и незначительное, но улучшение оценок по сравнению с предыдущим кварталом практически по всем запрашиваемым индикаторам кроме ценовых параметров. В частности, об «очень хорошем» и «хорошем» своём м атериальном положении сообщили в отчётном квартале 12,9% (0,3 и 12,6%, со ответственно) участников опроса. Выявленное значение на 1,2 п. п. выше, чем в I кв. т. г. Однако итоговый результат отчётного квартала на 0,8 п. п. хуже, чем среднеквартальный за 2024 г. Одновременно с ростом доли респондентов, отмечающих «хорошее» и «очень хорошее» текущее материальное положение, в отчётном квартале наблюдалось увеличение числа тех, кто отмечал «плохое» и «очень плохое» материальное состояние (17,3%) (15,8 и 1,5%, соответственно). В I кв. т. г. относительное значение данного показателя составляло (15,7%). Основная доля ответов (69,8%) пришлась на оценку среднего материального состояния. Рис. 4. Ðàñïðåäåëåíèå ìíåíèé ðåñïîíäåíòîâ î òåêóùåì ìàòåðèàëüíîì ïîëîæåíèè Доля от общего числа респондентов, % 0,3 12,6 69,8 15,8 1,5 0,0 очень хорошее хорошее среднее плохое очень плохое затрудняюсь ответить', chunk_id='Consumer_sentiment_2Q2025:21', year=2025, distance=0.9124614596366882), Chunk(text='5 Среди пяти компонент, входящих в структуру сводного ИПУ в отчётном квартале, наблюдалась преимущественно позитивная динамика по сравнению с пре ...
#  RAGAgentAnswer(dataset_row_id='536bf426-d85f-472c-b434-6796078cf647', answer='Согласно данным 2019 года, баланс отрицательных и положительных мнений респондентов об экономической ситуации составил 30 процентных пунктов, при этом 42% респондентов оценили ситуацию отрицательно, 12% - положительно, а 46% высказались нейтрально.', retrieved_chunks=[Chunk(text='Потребительские настроения населения во II квартале 2019 года 8 темпы позитивной динамик и ИПУ сохранятся, то для выхода индикатора в нейтральную зону понадобится более двух лет К заметным отрицательным моментам, выявленным в ходе опр оса за II квартал, можно отнести, во-первых, тот факт, что доли негативных мнени й респондентов по всем вопросам анкеты превышали доли позитивны х. Во -вторых, слишком контрастное распределение ответов населения на вопрос об изменении общей экономической ситуации в стране во II квартале по сравнению с I кварталом. Так, отрицательно оценили динамику экономических событий за этот период 42% респондентов, 12% дали положительные оценки и 46% высказались нейтрально. В результате, баланс отрицательных и положительны х мнений составил 30 п. п. Подобный разрыв можно охарактеризовать как достаточно негативное явление. Причем свои негативные мнения респонденты высказали на фоне относительно благоприятной , исходя из текущих данных Росстата, макроэкономической ситуации в ст ране. В частности, хотя и незначительными темпами двенадцать кварталов подряд (по сравнению с соответствующим периодом предыдущего года) растет ВВП, наблюдаются позитивные темпы роста всех базовых видов экономической деятельности, растет товарооборот как п родовольственных, та к и непродовольственных товаров. Правда, во многом рост указанных показателей определяется высокими темпами потребительского кредитования', chunk_id='Potrebitelskie_ozhidaniya_2_2019:14', year=2019, distance=0.6054031848907471), Chunk(text='Потребительские настроения населения во II квартале 2019 года 6 Распределение ответов на отдельные вопросы Анализ распределения мнений респондентов относительно их личного материального положени я, условий для крупных покупок и сбережений , а также ожидаемой в следующем году инфляции позволяет более детально изучить эти аспекты формирования потребительской уверенности, в значительной степени определяющи е состояние платежеспособного спроса на товары и услуги со стороны населения. Рис. 6. Распределение мнений респондентов в I квартале 2019 г. Доля от общего числа респондентов, % (данные за второй квартал Росстат пока не опубликовал) Текущее материальное положение Ожидаемое изменение цен Условия для крупных покупок Условия для формирования сбережений Источник: Росстат . Весьма редко участники опроса определенно позитивно оценивали свое личное материальное положение, сложившиеся условия для совершения крупных покупок и формирования сбережений: доля «очень благоприятных» оценок этих показателей не превышала 0,3-0,4%. Умеренно позитивного мнения придержи вался лишь один из десяти респондентов, превалировали нейтральные и умеренно негативные настроения. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% потребителей. Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала', chunk_id='Potrebitelskie_ozhidaniya_2_2019:9', year=2019, distance=0.609157383441925), Chunk(text='. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% потребителей. Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала. В частности, доля «неблагоприятных» оценок условий для крупных покупок и сбережений выросла с 4 5,5 до 50% и с 57 до 60% соответственно при некотором снижении доли «благоприятных» оценок. Аналогично, с 26 до 30% выросла доля ...
#  RAGAgentAnswer(dataset_row_id='e3453b4c-2d2a-4569-899d-f731158e2d36', answer='В позитивной зоне находятся следующие социальные показатели по данным 2025 года:\n\n1. Индекс ожидаемых изменений экономической ситуации в стране достиг нейтрального значения (0%).\n2. Индекс произошедших изменений в экономике России за последний год вырос на 6 процентных пунктов, что является одним из лучших результатов с 2018 года.\n3. Показатель «благоприятность условий для сбережений» имеет лучшее поквартальное значение за всё время проведения опросов, составив (-20%).', retrieved_chunks=[Chunk(text='. Значит за год произошло некоторое ухудшение состояния важнейшего социального индикатора – «неравенство в доходах». Однако следует обратить внимание, что зафиксированн ое Росстатом в I кв. значение коэффициента Джини (0,402) находится по международн ой классификации на нижней границе нейтрального уровня и не является слишком высоким. Так, по оценочной методологии Всемирного банка, при страновых сравнениях принято считать значение коэффициента Джини (распределение по кривой Лоренца) от 0,0 до 0,350, как благоприятный уровень, от 0,351 до 0,500, как нейтральный и от 0,501 до 1,0, как небла гоприятный. Российский коэффициент Джини смотрится лучше, чем, например, в США и Китае , но уступает практически всем европейским странам. Одним из главных негативных факторов, тормозящих ро ст благосостояния населения, является рост цен на товары и услуги (инфляция). Так, исходя из обобщённых мнений респондентов, в от чётном квартале лишь 2,2% из них надеются на снижение цен в течении ближайшего г ода (0,3% - значительного и 1,9 – незначительного). Об ожидаемом росте цен в своих от ветах констатировала подавляющая доля участников опроса (86%). Чуть более 10% респондентов (11,8%) надеются на сохранение текущих цен на товары и услуги в интервале ближайшего года. 1,3 12,8 42,8 29 13,5 0,6 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить', chunk_id='Consumer_sentiment_2Q2025:24', year=2025, distance=0.9912769198417664), Chunk(text='10 Рис. 5. Ðàñïðåäåëåíèå ìíåíèé ðåñïîíäåíòîâ îá óñëîâèÿõ äëÿ êðóïíûõ ïîêóïîê Доля от общего числа респондентов, % Рис. 6. Ðàñïðåäåëåíèå ìíåíèé ðåñïîíäåíòîâ îá îæèäàåìûõ èçìåíåíèÿõ öåí Доля от общего числа респондентов, % 0,7 11,6 45,6 29,4 12,5 0,3 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить 0,3 1,9 11,6 39,0 47,0 0,2 значительно снизятся незначительно снизятся останутся на прежнем уровне незначительно возрастут значительно возрастут затрудняюсь ответить', chunk_id='Consumer_sentiment_2Q2025:22', year=2025, distance=0.9966367483139038), Chunk(text='3 Центр конъюнктурных исследований Института статисти ческих исследований и экономики знаний НИУ ВШЭ представляет информационно -аналитический материал о потребительских настроениях населения России
#  RAGAgentAnswer(dataset_row_id='6192474e-db88-47a1-9c27-5c5e89d5e430', answer='В контексте недостаточно данных, чтобы определить процент респондентов, оказавшихся в затруднительном положении при ответе на вопрос о факторах, влияющих на формирование сбережений.', retrieved_chunks=[Chunk(text='. Среди индикаторов, не входящих в расчёт сводного ИП У, на наш взгляд, следует обратить внимание на показатель «благоприятность условий для сбережений» . Баланс мнений респондентов (улучшение-ухудшение) в оценке данного показателя в отчётном квартале составил (-20%). Это лучшее поквартальное значение за всё время проведения потребительских опросов населения. Исходя из позитивной динамики показателей «благопри ятность условий для сбережений» и «благоприятность условий для крупных покупок», которая наблюдается в последних опросах, а также учитывая продолжающийся рост депозитных вкладов и объёмов товарооборота розничной торговли, можно утверждать, что население страны функционирует в настоящее время одновременно в потребительской и сберегательной модели поведения с небольшим приоритетом к последней. Правда это преим ущество, в основном, относится к высокодоходной части общества, которая может себе п озволить практически безболезненно формировать депозитную базу в целях получения в дал ьнейшем достаточно существенных доходов от собственности. По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составлял 61,5 трлн. руб', chunk_id='Consumer_sentiment_2Q2025:10', year=2025, distance=0.8796815872192383), Chunk(text='5 Среди пяти компонент, входящих в структуру сводного ИПУ в отчётном квартале, наблюдалась преимущественно позитивная динамика по сравнению с предыдущим кварталом. \x01 Индекс произошедших изменений в личном материальном положении в II кв. 2025 г. по сравнению с I кв. 2025 г. возрос на 1 п. п. и составил (-8%); \x01 Индекс ожидаемых изменений личного материального по ложения в отчётном периоде сохранился на уровне предыдущего квартала – (-3%); \x01 Индекс произошедших изменений в экономике России за последний год в отчётном квартале вырос на 6 п. п. относительно предыдущего квартала, составив (-10%). Это один из лучших результатов с 2018 г.; \x01 Индекс ожидаемых изменений экономической ситуации в стране в анализируемом периоде вырос на 4 п. п., достигнув нейтрального значения, – (0%); \x01 Индекс благоприятности условий для крупных покупок вырос на 1 п. п., составив (-21%). Рис. 2. Êîìïîíåíòû ÈÏÓ— ÷àñòíûå èíäåêñû èçìåíåíèÿ ýêîíîìè÷åñêîé ñèòóàöèè â Ðîññèè, ëè÷íîãî ìàòåðèàëüíîãî ïîëîæåíèÿ, à òàêæå áëàãîïðèÿòíîñòè óñëîâèé äëÿ êðóïíûõ ïîêóïîê Балансы, % Источник: Росстат. Среди индикаторов, не входящих в расчёт сводного ИП У, на наш взгляд, следует обратить внимание на показатель «благоприятность условий для сбережений» . Баланс мнений респондентов (улучшение-ухудшение) в оценке данного показателя в отчётном квартале составил (-20%). Это лучшее поквартальное значение за всё время проведения потребительских опросов населения', chunk_id='Consumer_sentiment_2Q2025:9', year=2025, distance=0.9216424822807312), Chunk(text='. Правда это преим ущество, в основном, относится к высокодоходной части общества, которая может себе п озволить практически безболезненно формировать депозитную базу в целях получения в дал ьнейшем достаточно существенных доходов от собственности. По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составлял 61,5 трлн. руб. Это примерно годовой приход по процентам по вкладам в районе 10 -60 -50 -40 -30 -20 -10 0 10 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
#  RAGAgentAnswer(dataset_row_id='635706a4-8be4-4550-9782-02bbaf29e2cd', answer='В 2019 году восприятие респондентов относительно неблагоприятных условий для крупных покупок изменилось в негативную сторону. Доля «неблагоприятных» оценок условий для крупных покупок выросла с 45,5% до 50%, а для сбережений — с 57% до 60%. Также увеличилась доля участников, характеризующих свое материальное положение как «плохое» или «очень плохое» с 26% до 30%.', retrieved_chunks=[Chunk(text='Потребительские настроения населения во II квартале 2019 года 6 Распределение ответов на отдельные вопросы Анализ распределения мнений респондентов относительно их личного материального положени я, условий для крупных покупок и сбережений , а также ожидаемой в следующем году инфляции позволяет более детально изучить эти аспекты формирования потребительской уверенности, в значительной степени определяющи е состояние платежеспособного спроса на товары и услуги со стороны населения. Рис. 6. Распределение мнений респондентов в I квартале 2019 г. Доля от общего числа респондентов, % (данные за второй квартал Росстат пока не опубликовал) Текущее материальное положение Ожидаемое изменение цен Условия для крупных покупок Условия для формирования сбережений Источник: Росстат . Весьма редко участники опроса определенно позитивно оценивали свое личное материальное положение, сложившиеся условия для совершения крупных покупок и формирования сбережений: доля «очень благоприятных» оценок этих показателей не превышала 0,3-0,4%. Умеренно позитивного мнения придержи вался лишь один из десяти респондентов, превалировали нейтральные и умеренно негативные настроения. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% потребителей. Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала', chunk_id='Potrebitelskie_ozhidaniya_2_2019:9', year=2019, distance=0.6103857159614563), Chunk(text='. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% потребителей. Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала. В частности, доля «неблагоприятных» оценок условий для крупных покупок и сбережений выросла с 4 5,5 до 50% и с 57 до 60% соответственно при некотором снижении доли «благоприятных» оценок. Аналогично, с 26 до 30% выросла доля участников опроса, характеризующих собственное материальное положение как «плохое» или «очень плохое». 0.3 6.963 27.3 2.3 0.2 очень хорошее хорошее среднее плохое очень плохое затрудняюсь ответить 0.1 1 8.5 40 50.2 0.2 значительно снизятся незначительно снизятся останутся на прежнем уровне незначительно возрастут значительно возрастут затрудняюсь ответить 0.4 9.2 38.6 33.2 16.9 1.7 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить 0.3 7.3 31.1 38 21.6 1.7 очень благоприятные скорее благоприятные "плюсов" и "минусов" одинаково скорее неблагоприятные совсем неблагоприятные затрудняюсь ответить', chunk_id='Potrebitelskie_ozhidaniya_2_2019:10', year=2019, distance=0.6230864524841309), Chunk(text='Потребительские настроения населения во II квартале 2019 года 8 темпы позитивной динамик и ИПУ сохранятся, то для выхода индикатора в нейтральную зону понадобится более двух лет К заметным отрицательным моментам, выявленным в ходе опр оса за II квартал, можно отнести, во-первых, тот факт, что доли негативных мнени й респондентов по всем вопросам анкеты превышали доли позитивны х. Во -вторых, слишком контрастное распределение ответов населения на вопрос об изменении общей экономической ситуации в стране во II квартале по сравнению с I кварталом. Так, отрицательно оценили динамику экономических событий за этот пе ...
#  RAGAgentAnswer(dataset_row_id='0ea06009-054d-427e-bd67-40579b294330', answer='В 2025 году более высокая инфляция затрагивает низкодоходное население, которое не имеет возможности формировать банковские сбережения. У них инфляция, как правило, на несколько процентов выше, чем у высокодоходного населения, из-за большей доли затрат на продовольственные товары, цены на которые растут быстрее.', retrieved_chunks=[Chunk(text='6 трлн. руб. в виде дохода от собственности. Частично , именно интенсивный рост доходов от собственности в виде процентов по вкладам является заметным драйвером общего роста доходов. Учитывая, что, по данным Росстата, верхняя пятая (с наивысшими доходами) двадцатипроцентная группа населения концентрирует у себя около половины всех доходов населения (46,2%), можно предположить, что именно э та группа является основным держателем депозитов на банковских счетах, и, соотв етственно, они же являются преимущественными получателями доходов от собственности. Естественно, получатели процентов по депозитам могут этими финансовыми ресурсами минимизировать инфляционное давление, тратя получен ные от процентов по депозитам практически «вертолётные деньги» на частичное погаш ение роста цен на товары и услуги. Именно этот механизм высокодоходного населения, име ющего депозитную базу, объясняет употребляемый «слоган», что инфляция – это «налог н а бедных», т. е. на людей, не имеющих возможности в достаточном объёме формировать свои б анковские сбережения и «отбивать» полученными процентами рост цен. Исходя из изложенн ого, инфляция у низкодоходного населения, как правило, на несколько процентов выше , чем у высокодоходного населения. Вдобавок, у низкодоходного населения в структуре по требления всегда заметно выше доля затрат на «продовольственные товары», чем у высокодоходного. А рост цен преимущественно выше в «продовольствии», чем на непродовольственные товары и услуги', chunk_id='Consumer_sentiment_2Q2025:12', year=2025, distance=0.899036705493927), Chunk(text='. Среди индикаторов, не входящих в расчёт сводного ИП У, на наш взгляд, следует обратить внимание на показатель «благоприятность условий для сбережений» . Баланс мнений респондентов (улучшение-ухудшение) в оценке данного показателя в отчётном квартале составил (-20%). Это лучшее поквартальное значение за всё время проведения потребительских опросов населения. Исходя из позитивной динамики показателей «благопри ятность условий для сбережений» и «благоприятность условий для крупных покупок», которая наблюдается в последних опросах, а также учитывая продолжающийся рост депозитных вкладов и объёмов товарооборота розничной торговли, можно утверждать, что население страны функционирует в настоящее время одновременно в потребительской и сберегательной модели поведения с небольшим приоритетом к последней. Правда это преим ущество, в основном, относится к высокодоходной части общества, которая может себе п озволить практически безболезненно формировать депозитную базу в целях получения в дал ьнейшем достаточно существенных доходов от собственности. По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составлял 61,5 трлн. руб', chunk_id='Consumer_sentiment_2Q2025:10', year=2025, distance=0.9839462041854858), Chunk(text='. Исходя из изложенн ого, инфляция у низкодоходного населения, как правило, на несколько процентов выше , чем у высокодоходного населения. Вдобавок, у низкодоходного населения в структуре по требления всегда заметно выше доля затрат на «продовольственные товары», чем у высокодоходного. А рост цен преимущественно выше в «продовольствии», чем на непродовольственные товары и услуги. Следует обратить внимание, что помимо 61,5 трлн. ру блёвых депозитов у российского населения в апреле т. г. было сосредоточено примерн о 3 трлн. руб. на валютных счетах (в пересчёте на рубли) и 10,5 трлн. руб. в виде остатков наличных денег на руках. Суммарно это составляет чуть более 75 трлн. руб. или почти два годовых государственных бюджета России. Это сама ...

# %%
from evaluation import evaluate

df_metrics = evaluate(
    answers=results,
    dataset=df_test,
    client=client,
    model=MODEL,
    overlap_threshold=0.3,
    compute_faithfulness=True,
)

print(f"\u2705 Оценка завершена: {df_metrics.shape[0]} строк, {df_metrics.shape[1]} колонок")
df_metrics.head(10)
# Out:
# Retrieval metrics: 100%|██████████| 150/150 [00:00<00:00, 2756.13it/s]
# Faithfulness: 100%|██████████| 150/150 [02:04<00:00,  1.20it/s]
# ✅ Оценка завершена: 150 строк, 9 колонок
#                                      id  \
# 0  e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1  c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2  7e727f79-c6ff-4ff0-b101-bcec2b0f7260
# 3  d52e6df3-d5ad-404e-9da9-f6f1855d16df
# 4  536bf426-d85f-472c-b434-6796078cf647
# 5  e3453b4c-2d2a-4569-899d-f731158e2d36
# 6  a3ae1b1c-a296-4e85-b8df-6ca1ed2093d0
# 7  25a2eff0-2893-471f-a145-20aa63633e13
# 8  49287b9e-2dad-4902-a389-bc0a34494dfc
# 9  6192474e-db88-47a1-9c27-5c5e89d5e430
#
#                                             question  precision  recall   f1  \
# 0  В 2019 году как изменился индекс потребительск...       0.25     1.0  0.4
# 1  Согласно данным 2025 года, какой фактор являет...       0.25     1.0  0.4
# 2  Согласно данным 2019 года, что является основн...       0.25     1.0  0.4
# 3  Какой процент респондентов в 2025 году затрудн...       0.25     1.0  0.4
# 4  Согласно данным 2019 года, какой был баланс от...       0.25     1.0  0.4
# 5  Согласно данным 2025 года, какие социальные по...       0.00     0.0  0.0
# 6  В 2025 году какова связь между потребительским...       0.25     1.0  0.4
# 7  В 2019 году какое место в рейтинге стран ЕС по...       0.25     1.0  0.4
# 8  Какая доля населения в 2025 году в основном фо...       0.25     1.0  0.4
# 9  Какой процент респондентов оказался в затрудни...       0.25     1.0  0.4
#
#    mrr  map     ndcg  faithfulness
# 0  1.0  1.0  1.00000      0.500000
# 1  1.0  1.0  1.00000      1.000000
# 2  1.0  1.0  1.00000      1.000000
# 3  1.0  1.0  1.00000      0.000000
# 4  1.0  1.0  1.00000      1.000000
# 5  0.0  0.0  0.00000      1.000000
# 6  1.0  1.0  1.00000      1.000000
# 7  1.0  1.0  1.00000      1.000000
# 8  1.0  1.0  1.00000      0.666667
# 9  0.5  0.5  0.63093      1.000000

# %% [markdown]
# ---
# ## 5. Анализ результатов

# %%
metric_cols = ["precision", "recall", "f1", "mrr", "map", "ndcg", "faithfulness"]
display_names = ["Precision@K", "Recall@K", "F1@K", "MRR", "MAP", "NDCG@K", "Faithfulness"]

summary = df_metrics[metric_cols].mean()
summary.index = display_names

print("=" * 45)
print("  ИТОГОВЫЕ МЕТРИКИ КАЧЕСТВА RAG-АГЕНТА")
print("=" * 45)
for name, val in summary.items():
    bar = "\u2588" * int(val * 30) + "\u2591" * (30 - int(val * 30))
    print(f"  {name:<15} {val:.4f}  {bar}")
print("=" * 45)
# Out:
# =============================================
#   ИТОГОВЫЕ МЕТРИКИ КАЧЕСТВА RAG-АГЕНТА
# =============================================
#   Precision@K     0.2567  ███████░░░░░░░░░░░░░░░░░░░░░░░
#   Recall@K        0.9622  ████████████████████████████░░
#   F1@K            0.4004  ████████████░░░░░░░░░░░░░░░░░░
#   MRR             0.8794  ██████████████████████████░░░░
#   MAP             0.8606  █████████████████████████░░░░░
#   NDCG@K          0.8912  ██████████████████████████░░░░
#   Faithfulness    0.8543  █████████████████████████░░░░░
# =============================================

# %%
# Сводная таблица
df_summary = pd.DataFrame(
    list(zip(display_names, summary.values)),
    columns=["Метрика", "Значение"],
)
df_summary["Значение"] = df_summary["Значение"].round(4)
df_summary
# Out:
#         Метрика  Значение
# 0   Precision@K    0.2567
# 1      Recall@K    0.9622
# 2          F1@K    0.4004
# 3           MRR    0.8794
# 4           MAP    0.8606
# 5        NDCG@K    0.8912
# 6  Faithfulness    0.8543

# %%
# Распределение метрик
df_metrics[metric_cols].describe().round(4)
# Out:
#        precision    recall        f1       mrr       map      ndcg  \
# count   150.0000  150.0000  150.0000  150.0000  150.0000  150.0000
# mean      0.2567    0.9622    0.4004    0.8794    0.8606    0.8912
# std       0.0706    0.1651    0.0795    0.2620    0.2710    0.2227
# min       0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
# 25%       0.2500    1.0000    0.4000    1.0000    1.0000    1.0000
# 50%       0.2500    1.0000    0.4000    1.0000    1.0000    1.0000
# 75%       0.2500    1.0000    0.4000    1.0000    1.0000    1.0000
# max       0.7500    1.0000    0.8571    1.0000    1.0000    1.0000
#
#        faithfulness
# count      150.0000
# mean         0.8543
# std          0.3198
# min          0.0000
# 25%          1.0000
# 50%          1.0000
# 75%          1.0000
# max          1.0000

# %%
# Худшие вопросы по F1
worst = df_metrics.nsmallest(5, "f1")[["id", "question", "precision", "recall", "f1", "faithfulness"]]
worst
# Out:
#                                        id  \
# 5    e3453b4c-2d2a-4569-899d-f731158e2d36
# 82   0d31e27e-6937-474a-9b4b-0fb609ddfcfe
# 127  f8c9648c-66c4-4d72-9c04-d3b0139ed186
# 124  803f755b-c612-4d1f-9ef0-51274f872db6
# 46   81b854bd-5b3c-4b43-ae80-c9755f76e36e
#
#                                               question  precision    recall  \
# 5    Согласно данным 2025 года, какие социальные по...       0.00  0.000000
# 82   Сколько представителей взрослого населения уча...       0.00  0.000000
# 127  Каким образом изменились представления людей о...       0.00  0.000000
# 124  Как изменились ожидания населения относительно...       0.25  0.333333
# 46   Какой уровень потребительской уверенности в Ро...       0.25  0.500000
#
#            f1  faithfulness
# 5    0.000000           1.0
# 82   0.000000           1.0
# 127  0.000000           1.0
# 124  0.285714           1.0
# 46   0.333333           1.0

# %%
# Лучшие вопросы по F1
best = df_metrics.nlargest(5, "f1")[["id", "question", "precision", "recall", "f1", "faithfulness"]]
best
# Out:
#                                       id  \
# 42  17c8527d-0880-40b4-b265-5d30a42403a0
# 33  91bc2a46-4eb8-4d9e-919b-9b85ef2fa1fa
# 85  4de4f4af-3c4b-4aa6-b40b-c2befb0c2c46
# 47  ad767644-e83f-43bb-9ce4-4bf56fef9e68
# 53  58afd835-8e1c-43e8-8290-c29546b2378c
#
#                                              question  precision    recall  \
# 42  Как изменения в коэффициенте Джини в 2025 году...       0.75  1.000000
# 33  Как изменились условия для крупных покупок и с...       0.50  1.000000
# 85  Какое место занимает Россия в рейтинге европей...       0.50  1.000000
# 47  Каковы были изменения в потребительской активн...       0.50  0.666667
# 53  Как изменения в уровне бедности и дифференциац...       0.50  0.666667
#
#           f1  faithfulness
# 42  0.857143          1.00
# 33  0.666667          1.00
# 85  0.666667          0.25
# 47  0.571429          1.00
# 53  0.571429          0.80
