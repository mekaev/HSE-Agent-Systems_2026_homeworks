# %% [markdown]
# # Критерии оценки ДЗ
#
# > **Версия LanceDB: `lancedb<0.20` !!!**
#
# Делаете прогоны на test_dataset, выбиваете максимум по метрикам. Я буду проверять на eval_dataset
#
# ---
#
# ## Базовые требования (4 балла)
#
# | # | Критерий | Баллы |
# |---|----------|-------|
# | 1 | Описан процесс подготовки данных (`data_preporation.py`, `embedder.py`) | 1 |
# | 2 | Описаны методы/функции для работы с векторной БД в `lance_db.py` (обязательно `read_all`) | 1 |
# | 3 | Данные записаны в БД и можно выполнить `read_all` | 1 |
# | 4 | Описан флоу retrieve и agent (`agent.py`, `retriever.py`) | 1 |
#
# ---
#
# ## Метрики качества (до 9 баллов)
#
# ### F1@K
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.50   | 1     |
# | > 0.75   | 2     |
# | > 0.90   | 3     |
#
# ### NDCG@K
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.65   | 1     |
# | > 0.75   | 2     |
# | > 0.90   | 3     |
#
# ### Faithfulness
#
# | Порог    | Баллы |
# |----------|-------|
# | > 0.75   | 1     |
# | > 0.85   | 2     |
# | > 0.95   | 3     |
#
# ---
#
# ## Лог эволюции (до 2 баллов)
#
# Оценивается индивидуально на основании полноты информации в `EVOLUTION.md`.
#
# ---
#
# ## Штрафы
#
# | Условие | Штраф |
# |---------|-------|
# | Суммарный объём всех передаваемых для генерации чанков > 6000 символов | −100500 баллов |
# | Использовали дополнительные библиотеки и не положили requirements.txt | −100500 баллов |
#
# ---
#
# **Максимум: 15 баллов** (4 базовых + 9 метрики + 2 эволюция)

# %% [markdown]
# # Валидация RAG-агента через модуль `evaluation.py`
#
# Демонстрация полного пайплайна оценки:
# 1. Подключаемся к векторному хранилищу и создаём агента
# 2. Загружаем тестовый датасет
# 3. Прогоняем агента на всех вопросах (многопоточно)
# 4. Вызываем `evaluate()` — получаем DataFrame с 7 метриками
# 5. Анализируем результаты

# %% [markdown]
# ---
# ## 0. Подготовка

# %%
import warnings

warnings.filterwarnings("ignore")

import sys
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm


def _find_project_root(start: Path) -> Path:
    for p in (start, *start.parents):
        if (p / "pyproject.toml").exists():
            return p
    return start


PROJECT_ROOT = _find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import settings
from openai import OpenAI

# %%
client = OpenAI(
    base_url="https://api.polza.ai/api/v1",
    api_key=settings.polza_ai_api_key,
)

MODEL = "openai/gpt-4o-mini"

# %% [markdown]
# ---
# ## 1. Подключаемся к векторному хранилищу и создаём агента

# %%
import lancedb

VECTORSTORE_DIR = "lance_db/vectorstore"
TABLE_NAME = "chunks"

db = lancedb.connect(VECTORSTORE_DIR)
table = db.open_table(TABLE_NAME)

print(f"\u2705 Таблица '{TABLE_NAME}' открыта: {table.count_rows()} строк")
# Out:
# ✅ Таблица 'chunks' открыта: 142 строк

# %%
from agent import RAGAgent, RAGAgentAnswer, TOOLS_SCHEMA, get_tool_functions

TOOL_FUNCTIONS = get_tool_functions(table, client)

agent = RAGAgent(
    client=client,
    model=MODEL,
    tools_schema=TOOLS_SCHEMA,
    tool_functions=TOOL_FUNCTIONS,
)

print("\u2705 Агент готов")
# Out:
# ✅ Агент готов

# %% [markdown]
# ---
# ## 2. Загрузка тестового датасета
#
# Датасет: `data/test_dataframe.xlsx` — 150 вопросов с ground truth.
#
# | Колонка | Описание |
# |---------|----------|
# | `id` | Уникальный идентификатор вопроса |
# | `question` | Вопрос на естественном языке |
# | `ground_truth_chunks` | Эталонные чанки (строковое представление списка) |
# | `document` | Год отчёта (2019 / 2025) |

# %%
df_test = pd.read_excel("data/test_dataframe.xlsx")
print(f"Размер: {df_test.shape}")
print(f"Колонки: {list(df_test.columns)}")
# df_test = df_test.head(20)
df_test.head(3)
# Out:
# Размер: (150, 4)
# Колонки: ['id', 'question', 'relevant_text', 'document']
#                                      id  \
# 0  e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1  c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2  7e727f79-c6ff-4ff0-b101-bcec2b0f7260
#
#                                             question  \
# 0  В 2019 году как изменился индекс потребительск...
# 1  Согласно данным 2025 года, какой фактор являет...
# 2  Согласно данным 2019 года, что является основн...
#
#                                        relevant_text  document
# 0  ['Как мы предполагали при анализе результатов ...      2019
# 1  ['Одним из главных негативных факторов, тормоз...      2025
# 2  ['Очевидно, что основным фактором, определяющи...      2019

# %% [markdown]
# ---
# ## 3. Прогон агента на тестовом датасете
#
# Запускаем агента на каждом вопросе и сохраняем `list[RAGAgentAnswer]`.
# Это **дорогая операция** (150 вопросов × N API-вызовов), поэтому используем многопоточность.

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed


def _run_single(idx: int, row_id: str, question: str, agent: RAGAgent) -> tuple[int, RAGAgentAnswer]:
    """Один вызов агента (для параллельного запуска)."""
    try:
        result = agent.run(question, verbose=False, dataset_row_id=row_id)
    except Exception as e:
        print(f"  [Ошибка] вопрос {idx}: {e}")
        result = RAGAgentAnswer(dataset_row_id=row_id, answer=f"[Ошибка: {e}]", retrieved_chunks=None)
    return idx, result


def run_evaluation(df: pd.DataFrame, agent: RAGAgent, max_workers: int = 4) -> list[RAGAgentAnswer]:
    """Прогнать агента на всех вопросах (многопоточно)."""
    results: list[RAGAgentAnswer | None] = [None] * len(df)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(_run_single, idx, row["id"], row["question"], agent): idx for idx, row in df.iterrows()
        }
        for future in tqdm(as_completed(futures), total=len(futures), desc="Прогон агента"):
            idx, result = future.result()
            results[idx] = result

    return results

# %%
results = run_evaluation(df_test, agent)

print(f"\nВсего результатов: {len(results)}")
print(f"С чанками: {sum(1 for r in results if r.retrieved_chunks)}")
print(f"Без чанков (None): {sum(1 for r in results if not r.retrieved_chunks)}")
# Out:
# Прогон агента:   0%|          | 0/150 [00:00<?, ?it/s]
# Прогон агента: 100%|██████████| 150/150 [03:29<00:00,  1.40s/it]
# Всего результатов: 150
# С чанками: 150
# Без чанков (None): 0

# %% [markdown]
# ---
# ## 4. Оценка через `evaluation.evaluate()`
#
# Весь расчёт метрик — **одна строка**. Модуль `evaluation.py` принимает:
# - `answers`: `list[RAGAgentAnswer]` — ответы агента
# - `dataset`: `pd.DataFrame` — тестовый датасет с ground truth
# - `client` + `model` — для вычисления Faithfulness (LLM-as-judge)
#
# Возвращает `pd.DataFrame` с метриками по каждому вопросу.

# %%
df_test
# Out:
#                                        id  \
# 0    e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1    c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2    7e727f79-c6ff-4ff0-b101-bcec2b0f7260
# 3    d52e6df3-d5ad-404e-9da9-f6f1855d16df
# 4    536bf426-d85f-472c-b434-6796078cf647
# ..                                    ...
# 145  17fc34cc-b8eb-49f0-b384-1d1db1998846
# 146  60a79f64-8f20-44dc-955e-8e8deee332e8
# 147  f5995543-80ec-4eb6-a0e2-fdf0b5d0de05
# 148  635706a4-8be4-4550-9782-02bbaf29e2cd
# 149  0ea06009-054d-427e-bd67-40579b294330
#
#                                               question  \
# 0    В 2019 году как изменился индекс потребительск...
# 1    Согласно данным 2025 года, какой фактор являет...
# 2    Согласно данным 2019 года, что является основн...
# 3    Какой процент респондентов в 2025 году затрудн...
# 4    Согласно данным 2019 года, какой был баланс от...
# ..                                                 ...
# 145  Согласно данным 2025 года, какой процент респо...
# 146  обобщающий индекс потребительской уверенности ...
# 147  В 2025 году что является важнейшим конъюнктурн...
# 148  Как изменилось восприятие респондентов относит...
# 149  В 2025 году какая часть населения сталкивается...
#
#                                          relevant_text  document
# 0    ['Как мы предполагали при анализе результатов ...      2019
# 1    ['Одним из главных негативных факторов, тормоз...      2025
# 2    ['Очевидно, что основным фактором, определяющи...      2019
# 3                      ['затрудняюсь ответить — 0,6%']      2025
# 4    ['В результате, баланс отрицательных и положит...      2019
# ..                                                 ...       ...
# 145                  ['- затрудняюсь ответить — 0,3%']      2025
# 146  ['Обобщающий индекс потребительской уверенност...      2025
# 147  ['Именно ожидания людей и бизнеса являются важ...      2025
# 148  ['аспределение мнений респондентов сместилось ...      2019
# 149  ['на людей, не имеющих возможности в достаточн...      2025
#
# [150 rows x 4 columns]

# %%
results
# Out:
# [RAGAgentAnswer(dataset_row_id='e876ec3b-7442-4145-99d0-d6bb85fd982d', answer='В 2019 году индекс потребительской уверенности (ИПУ) в России продолжил восстанавливаться после резкого ухудшения в конце предыдущего года. Во II квартале 2019 года индекс вырос на 1 процентный пункт по сравнению с предыдущим кварталом и достиг отметки -15%. Это значение практически соответствует среднему долговременному уровню данного индикатора за всю двадцатилетнюю историю его расчёта.', retrieved_chunks=[Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.4256684482097626), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=12, year=2019, distance=0.4935418665409088), Chunk(text='Как мы предполагали при анализе результатов предыдущего раунда обследования, позитивная коррекция индекса потребительской уверенности, начавшаяся в I квартале 2019 г., продолжилась во II квартале. Правда, темпы улучшения показателя остались минимальными (по 1 п. п', chunk_id=33, year=2019, distance=0.5172268152236938), Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=0.530777096748352), Chunk(text='---\n\nВо II квартале 2019 г. продолжилось постепенное восстановление совокупных потребительских настроений российского населения после их резкого ухудшения в конце предыдущего года. Индекс потребительской уверенности (ИПУ) вновь вырос на 1 п. п. относительно параметров предыдущего квартала и достиг отметки (-15%), что практически соответствует среднему долговременному уровню данного индикатора за всю двадцатилетнюю историю его расчёта.\n\n---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*', chunk_id=11, year=2019, distance=0.5611154437065125)]),
#  RAGAgentAnswer(dataset_row_id='c7304cf4-9ebf-461b-acce-4dc987c21bcc', answer='Согласно данным 2025 года, одним из главных негативных факторов, тормозящих рост благосостояния населения, является рост цен на товары и услуги (инфляция).', retrieved_chunks=[Chunk(text='Одним из главных негативных факторов, тормозящих рост благосостояния населения, является рост цен на товары и услуги (инфляция).', chunk_id=129, year=2025, distance=0.653832733631134), Chunk(text='Одним из главных негативных факторов, тормозящих рост благосостояния населения, является рост цен на товары и услуги (инфляция).', chunk_id=137, year=2025, distance=0.653832733631134), Chunk(text='К сожалению, высокая вероятность снижения индекса потребительской уверенности в ближайшие годы из-за демографических невзгод 90-х годов двадцатого столетия, выраженных в серьёзном сокращении рождаемости, и даже из-за «эхо» Великой Отечественной войны. В настоящее время Россия вступила в фазу изменения демографической пирамиды не только в виде сокращения трудоспособного населения, но и сокращения численности средневозрастной когорты людей', chunk_id=113, year=2025, distance=0.7845219373703003), Chunk(text='Сегодня проблема повышения реальных располагаемых денежных доходов населения, которые четыре года подряд падали, а в прошлом году перешли, по данным Росстата, в стагнационный режим, является одной из главных задач, определяющих развитие экономики. Нельзя забывать, что падение доходов у определённой части населения практически всегда сопровождается увеличением неравенства в доходах, а большинство социальных показателей, являющихся индикаторами, находятся на крайне негативных уровнях.', chunk_id=45, year=2019, distance=0.9111136794090271), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=0.9520684480667114)]),
#  RAGAgentAnswer(dataset_row_id='7e727f79-c6ff-4ff0-b101-bcec2b0f7260', answer='Согласно данным 2019 года, основным фактором, определяющим динамику потребительской уверенности россиян, являются реальные денежные доходы населения, а также текущий и ожидаемый уровень инфляции.', retrieved_chunks=[Chunk(text='Очевидно, что основным фактором, определяющим динамику потребительской уверенности россиян, являются реальные денежные доходы населения, а также текущий и ожидаемый уровень инфляции.', chunk_id=46, year=2019, distance=0.5298112630844116), Chunk(text='Как мы предполагали при анализе результатов предыдущего раунда обследования, позитивная коррекция индекса потребительской уверенности, начавшаяся в I квартале 2019 г., продолжилась во II квартале. Правда, темпы улучшения показателя остались минимальными (по 1 п. п', chunk_id=33, year=2019, distance=0.65538489818573), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.672372579574585), Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=0.7003031373023987), Chunk(text='## Потребительские настроения населения во II квартале 2019 года', chunk_id=49, year=2019, distance=0.7317047119140625)]),
#  RAGAgentAnswer(dataset_row_id='d52e6df3-d5ad-404e-9da9-f6f1855d16df', answer='В 2025 году информация о проценте респондентов, затруднившихся ответить на вопрос о своём финансовом состоянии, в доступных данных отсутствует. Если вам нужна информация за 2019 год, я могу её предоставить.', retrieved_chunks=[Chunk(text='. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% респондентов.', chunk_id=29, year=2019, distance=0.8584223985671997), Chunk(text='---\n\n  \n*Балансы, %*\n\n- до 30 лет — (-7%)  \n- 30–49 лет — (-11%)  \n- 50 лет и старше — (-13%)  \n\n## Потребительские настроения населения во II квартале 2019 года\n\n## Распределение ответов на отдельные вопросы анкеты', chunk_id=23, year=2019, distance=0.9452667832374573), Chunk(text='---\n\n  \n*Доля от общего числа респондентов, %*  \n*(данные за второй квартал Росстатом пока не опубликованы)*\n\n### Текущее материальное положение\n- очень хорошее — 0,3%  \n- хорошее — 6,9%  \n- среднее — 63,0%  \n- плохое — 27,3%  \n- очень плохое — 2,3%  \n- затрудняюсь ответить — 0,2%', chunk_id=25, year=2019, distance=0.9748985767364502), Chunk(text='Так, исходя из обобщённых мнений респондентов, в отчётном квартале лишь 2,2% из них надеются на снижение цен в течение ближайшего года (0,3% — значительного и 1,9% — незначительного). Об ожидаемом росте цен в своих ответах констатировало подавляющее большинство участников опроса (86%). Чуть более 10% респондентов (11,8%) надеются на сохранение текущих цен на товары и услуги в интервале ближайшего года.\n## Методологические примечания', chunk_id=138, year=2025, distance=0.975182294845581), Chunk(text='## Распределение ответов на отдельные вопросы анкеты\n\nАнализ распределения мнений респондентов относительно их личного материального положения, условий для крупных покупок и сбережений, а также ожидаемой в следующем году инфляции позволяет более детально изучить эти аспекты формирования потребительской уверенности, в значительной степени определяющие состояние платежеспособного спроса на товары и услуги со стороны населения.\n\n---', chunk_id=24, year=2019, distance=0.9818888306617737), Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=0.9609937071800232), Chunk(text='---\n\n  \n*Балансы, %*\n\n- до 30 лет — (-7%)  \n- 30–49 лет — (-11%)  \n- 50 лет и старше — (-13%)  \n\n## Потребительские настроения населения во II квартале 2019 года\n\n## Распределение ответов на отдельные вопросы анкеты', chunk_id=23, year=2019, distance=1.0806959867477417), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=1.0807725191116333), Chunk(text='## Распределение ответов на отдельные вопросы анкеты\n\nАнализ распределения мнений респондентов относительно их личного материального положения, условий для крупных покупок и сбережений, а также ожидаемой в следующем году инфляции позволяет более детально изучить эти аспекты формирования потребительской уверенности, в значительной степени определяющие состояние платежеспособного спроса на товары и услуги со стороны населения.\n\n---', chunk_id=24, year=2019, distance=1.1040431261062622), Chunk(text='---\n\n  \n*Балансы, %*\n\n- произошедшие изменения личного материального положения  \n- ожидаемые изменения личного материального положения  \n- произошедшие изменения в экономике России  \n- ожидаемые изменения в экономике России  \n\n---', chunk_id=15, year=2019, distance=1.11305832862854)]),
#  RAGAgentAnswer(dataset_row_id='536bf426-d85f-472c-b434-6796078cf647', answer='В 2019 году 42% респондентов отрицательно оценили динамику экономических событий, в то время как только 12% дали положительные оценки. Таким образом, баланс отрицательных и положительных мнений составил 30 процентных пунктов, что указывает на достаточно негативное восприятие экономической ситуации среди населения.', retrieved_chunks=[Chunk(text='. Так, отрицательно оценили динамику экономических событий за этот период 42% респондентов, 12% дали положительные оценки и 46% высказались нейтрально. В результате, баланс отрицательных и положительных мнений составил 30 п. п. Подобный разрыв можно охарактеризовать как достаточно негативное явление. Причём свои негативные мнения респонденты высказали на фоне относительно благоприятной, исходя из текущих данных Росстата, макроэкономической ситуации в стране', chunk_id=39, year=2019, distance=0.6852501034736633), Chunk(text='Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала. В частности, доля «неблагоприятных» оценок условий для крупных покупок и сбережений выросла с 4,5 до 50% и с 5,7 до 60% соответственно при некотором снижении доли «благоприятных» оценок. Аналогично, с 26 до 30% выросла доля участников опроса, характеризующих собственное материальное положение как «плохое» или «очень плохое».\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=30, year=2019, distance=0.7232291102409363), Chunk(text='- Позитивно оценили произошедшие за год изменения в экономике России 12% участников опроса, негативно — 42% (кварталом ранее — 11 и 45%);\n- Положительных изменений в экономике России через год ожидают 15% опрошенных, отрицательных — 29% (кварталом ранее — 16 и 33%).', chunk_id=10, year=2019, distance=0.7377285957336426), Chunk(text='К заметным отрицательным моментам, выявленным в ходе опроса за II квартал, можно отнести, во-первых, тот факт, что доли негативных мнений респондентов по всем вопросам анкеты превышали доли позитивных. Во-вторых, мнения респондентов распределение ответов населения на вопрос об изменении общей экономической ситуации в стране во II квартале по сравнению с I кварталом', chunk_id=38, year=2019, distance=0.8396393656730652), Chunk(text='✓ **Индекс ожидаемых изменений экономической ситуации в стране** в анализируемом периоде вырос на 4 п. п., достигнув нейтрального значения — (0%);\n\n✓ **Индекс благоприятности условий для крупных покупок** вырос на 1 п. п., составив (-21%).\n\n---\n\n  \n*Баланс, %*\n\n---', chunk_id=84, year=2025, distance=0.8623911142349243)]),
#  RAGAgentAnswer(dataset_row_id='e3453b4c-2d2a-4569-899d-f731158e2d36', answer='Согласно данным за 2025 год, социальные показатели, такие как уровень бедности и дифференциация доходов населения (неравенство), находятся в позитивной зоне. Это означает, что наблюдаются улучшения в этих областях, что положительно сказывается на мнении респондентов о экономическом росте и развитии экономики.', retrieved_chunks=[Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=0.8607159852981567), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=0.9661441445350647), Chunk(text='. Существенными индикаторами, которые оказывают влияние на мнение респондентов при оценке экономического роста и развития экономики, на наш взгляд, также являются изменения в уровне бедности и дифференциации доходов населения (неравенство). Исходя из последних данных официальной статистики Росстата, все эти перечисленные социальные показатели находятся в позитивной зоне.', chunk_id=78, year=2025, distance=0.9739493131637573), Chunk(text='К очевидным относительно позитивным изменениям, выявленным в итоговых результатах опроса населения во II квартале, можно отнести хотя и незначительный, но рост ИПУ во всех трёх наблюдаемых возрастных группах. Подобная позитивная солидарность достаточно редко встречалась в предыдущих квартальных потребительских опросах. Вместе с тем, ИПУ во всех возрастных группах пока ещё находится достаточно глубоко в отрицательной зоне. Если\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=36, year=2019, distance=1.0217519998550415), Chunk(text='---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.\n\nЦентр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал «Потребительские настроения населения во II квартале 2025 г.», подготовленный в рамках Программы фундаментальных исследований НИУ ВШЭ.', chunk_id=57, year=2025, distance=1.0293647050857544)]),
#  RAGAgentAnswer(dataset_row_id='a3ae1b1c-a296-4e85-b8df-6ca1ed2093d0', answer='В 2025 году наблюдается высокая прямая корреляция между потребительскими настроениями среднего класса и объемом экономики России (ВВП). С ростом потребительских настроений среднего класса всегда увеличивается и ВВП страны, и наоборот. Это указывает на то, что изменения в потребительских настроениях могут служить индикатором экономической активности и состояния экономики в целом.', retrieved_chunks=[Chunk(text='Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал о потребительских настроениях населения России в II кв. 2025 г. Обзор основан на результатах ежеквартального опроса потребителей (домашних хозяйств). Опрос проводился Федеральной службой государственной статистики во всех субъектах РФ, в нем приняли участие 5,1 тыс. человек в возрасте от 16 лет и старше, проживающих в частных домохозяйствах.\n\n---', chunk_id=63, year=2025, distance=0.6730592846870422), Chunk(text='Следует иметь в виду, что рост или снижение ИПУ в средневозрастной группе в подавляющем большинстве случаев обусловлен средней класс российской экономики имеет очень высокую прямую корреляцию с ростом или снижением объёма экономики России. С ростом потребительских настроений среднего класса всегда растёт и ВВП страны и наоборот.', chunk_id=106, year=2025, distance=0.6897286772727966), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=0.7464269399642944), Chunk(text='Возрастное распределение частного индекса ожидаемых изменений экономической ситуации в России свидетельствует о двух тенденциях. Во-первых, разнонаправленные изменения потребительских настроений в различных группах в течение последнего квартала привели к тому, что различия между ними почти нивелировались. И люди старшего возраста, и более молодые поколения придерживались практически одинаковых умеренно пессимистичных мнений относительно развития экономики страны в течение ближайших 12 месяцев', chunk_id=21, year=2019, distance=0.7852769494056702), Chunk(text='Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал о потребительских настроениях населения России во II квартале 2019 г. В обзоре использованы итоги опросов потребителей, в которых принимают участие более 5 тыс. человек в возрасте от 16 лет и старше, проживающих в частных домохозяйствах', chunk_id=6, year=2019, distance=0.7861539125442505)]),
#  RAGAgentAnswer(dataset_row_id='25a2eff0-2893-471f-a145-20aa63633e13', answer='В 2019 году в доступных данных не содержится информации о месте России в рейтинге стран ЕС по индексу потребительской уверенности. Если вам нужна информация по другим аспектам потребительских настроений, пожалуйста, уточните.', retrieved_chunks=[Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=0.5521459579467773), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=141, year=2025, distance=0.5884291529655457), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=54, year=2019, distance=0.5884291529655457), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.6324621438980103), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=12, year=2019, distance=0.6894471645355225)]),
#  RAGAgentAnswer(dataset_row_id='49287b9e-2dad-4902-a389-bc0a34494dfc', answer='В 2025 году основная доля депозитов формируется верхней пятой (с половиной доходов) двадцатипроцентной группы населения, которая концентрирует около половины всех доходов населения (46,2%). Это предполагает, что именно эта группа является основным держателем депозитов на банковских счетах.', retrieved_chunks=[Chunk(text='. Учитывая, что, по данным Росстата, верхняя пятая (с половиной доходов) двадцатипроцентная группа населения концентрирует у себя около половины всех доходов населения (46,2%), можно предположить, что именно эта группа является основным держателем депозитов на банковских счетах, и, соответственно, они же являются преимущественными получателями доходов от собственности.', chunk_id=90, year=2025, distance=0.9602710604667664), Chunk(text='Следует обратить внимание, что помимо 61,5 трлн. рублёвых депозитов у российского населения в апреле т. г. было сосредоточено примерно 3 трлн. руб. на валютных счетах (в пересчёте на рубли) и 10,5 трлн. руб. в виде остатков наличных денег на руках. Суммарно это составляет чуть более 75 трлн. руб. или почти два годовых государственных бюджета России. Это самая большая сумма сбережений населения на вкладах и наличных денег на руках за всё время послевоенных наблюдений.\n\n---', chunk_id=94, year=2025, distance=1.072554588317871), Chunk(text='По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составил 61,5 трлн. руб. Это примерно годовой приход по процентам по вкладам в районе 10', chunk_id=88, year=2025, distance=1.0833557844161987), Chunk(text='Исходя из позитивной динамики показателей «благоприятность условий для сбережений» и «благоприятность условий для крупных покупок», которая наблюдается в последних опросах, а также учитывая продолжающийся рост депозитных вкладов и объёмов товарооборота розничной торговли, можно утверждать, что население страны функционирует в настоящее время одновременно в потребительской и сберегательной модели поведения с небольшим приоритетом к последней', chunk_id=86, year=2025, distance=1.1130391359329224), Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=1.153428554534912)]),
#  RAGAgentAnswer(dataset_row_id='6192474e-db88-47a1-9c27-5c5e89d5e430', answer='В 2025 году 1,7% респондентов затруднились ответить на вопрос о факторах, влияющих на формирование сбережений.', retrieved_chunks=[Chunk(text='### Условия для формирования сбережений\n- очень благоприятные — 0,3%  \n- скорее благоприятные — 7,3%  \n- «плюсов» и «минусов» одинаково — 31,1%  \n- скорее неблагоприятные — 21,8%  \n- совсем неблагоприятные — 38,0%  \n- затрудняюсь ответить — 1,7%  \n\n---', chunk_id=27, year=2019, distance=0.9792877435684204), Chunk(text='✓ **Индекс произошедших изменений в личном материальном положении** в II кв. 2025 г. по сравнению с I кв. 2025 г. возрос на 1 п. п. и составил (-8%);\n\n✓ **Индекс ожидаемых изменений личного материального положения** в отчётном периоде сохранился на уровне предыдущего квартала — (-3%);\n\n✓ **Индекс произошедших изменений в экономике России за последний год** в отчётном квартале вырос на 6 п. п. относительно предыдущего квартала, составив (-10%). Это один из лучших результатов с 2018 г.;', chunk_id=83, year=2025, distance=1.0313538312911987), Chunk(text='---\n\n  \n*Баланс, %*\n\n---\n\nСреди индикаторов, не входящих в расчёт сводного ИПУ, на наш взгляд, следует обратить внимание на показатель **«благоприятность условий для сбережений»**. Баланс мнений респондентов (улучшение–ухудшение) в оценке данного показателя в отчётном квартале составил (-20%). Это лучшее поквартальное значение за всё время проведения потребительских опросов населения.', chunk_id=85, year=2025, distance=1.0703396797180176), Chunk(text='---\n\n  \n*Доля от общего числа респондентов, %*\n\n- значительно снизятся — 0,3%  \n- незначительно снизятся — 1,9%  \n- останутся на прежнем уровне — 11,6%  \n- незначительно возрастут — 39,0%  \n- значительно возрастут — 47,0%  \n- затрудняюсь ответить — 0,2%\n  \n*Доля от общего числа респондентов, %*', chunk_id=122, year=2025, distance=1.0918866395950317), Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=1.097057819366455)]),
#  RAGAgentAnswer(dataset_row_id='a89ab882-c7fc-427a-aa10-6a9741416be3', answer='В первом квартале 2019 года наблюдался провал в доходах населения на уровне -2,3%. Это значение указывает на снижение реальных доходов по сравнению с предыдущим периодом.', retrieved_chunks=[Chunk(text='Если прогнозировать динамику реальных доходов населения до конца текущего года, исходя из позитивного сценария, то можно с осторожностью предположить, что уже во II квартале 2019 г. мы не увидим такого провала в доходах, как в I квартале (-2,3%), затем по суммарным результатам за девять месяцев текущего года доходы приблизятся к отметке 0%. Далее, исходя из объявленной в октябре 2019 г', chunk_id=47, year=2019, distance=0.8092249035835266), Chunk(text='## Потребительские настроения населения во II квартале 2019 года', chunk_id=49, year=2019, distance=0.946685791015625), Chunk(text='В частности, об «очень хорошем» и «хорошем» своём материальном положении сообщили в отчётном квартале 12,9% (0,3 и 12,6%, соответственно) участников опроса. Выявленное значение на 1,2 п. п. выше, чем в I кв. т. г. Однако итоговый результат отчётного квартала на 0,8 п. п. хуже, чем среднеквартальный за 2024 г.', chunk_id=119, year=2025, distance=1.0206719636917114), Chunk(text='. Далее, исходя из объявленной в октябре 2019 г. индексации заработных плат бюджетникам, единовременного ранее повышения пенсий и других индексаций социальных выплат, в конце текущего года можно ожидать перехода реальных доходов в положительную зону, с итоговым', chunk_id=48, year=2019, distance=1.0362707376480103), Chunk(text='По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составил 61,5 трлн. руб. Это примерно годовой приход по процентам по вкладам в районе 10', chunk_id=88, year=2025, distance=1.0835728645324707)]),
#  RAGAgentAnswer(dataset_row_id='5373fefe-65da-416b-b526-3d77ba2f6d21', answer='В 2025 году, по сравнению с предыдущим кварталом, наблюдается незначительное улучшение оценок потребительской уверенности практически по всем запрашиваемым индикаторам, кроме оценочных параметров. Это говорит о том, что мнения респондентов стали более позитивными в отношении потребительской уверенности. \n\nК сожалению, конкретные цифры и более детальная информация о распределении мнений респондентов в 2025 году не были найдены в доступных данных.', retrieved_chunks=[Chunk(text='Анализ распределения мнений респондентов относительно отдельных показателей, формирующих потребительскую уверенность населения и представленных в пятикатегорийном интервале (от «очень хорошее» до «очень плохое»), показывает, хотя и незначительное, но улучшение оценок по сравнению с предыдущим кварталом практически по всем запрашиваемым индикаторам кроме оценочных параметров.', chunk_id=118, year=2025, distance=0.6727585196495056), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.6811398863792419), Chunk(text='Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала. В частности, доля «неблагоприятных» оценок условий для крупных покупок и сбережений выросла с 4,5 до 50% и с 5,7 до 60% соответственно при некотором снижении доли «благоприятных» оценок. Аналогично, с 26 до 30% выросла доля участников опроса, характеризующих собственное материальное положение как «плохое» или «очень плохое».\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=30, year=2019, distance=0.7051259875297546), Chunk(text='Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал о потребительских настроениях населения России в II кв. 2025 г. Обзор основан на результатах ежеквартального опроса потребителей (домашних хозяйств). Опрос проводился Федеральной службой государственной статистики во всех субъектах РФ, в нем приняли участие 5,1 тыс. человек в возрасте от 16 лет и старше, проживающих в частных домохозяйствах.\n\n---', chunk_id=63, year=2025, distance=0.705747663974762), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=12, year=2019, distance=0.7191899418830872)]),
#  RAGAgentAnswer(dataset_row_id='96502955-0a6f-45f6-8064-ce293bbf8d47', answer='Снижение индекса потребительской уверенности в 2025 году может быть обусловлено несколькими факторами:\n\n1. **Демографические изменения**: Высокая вероятность снижения индекса потребительской уверенности связана с демографическими невзгодами, возникшими в 90-х годах, что приводит к сокращению трудоспособного населения и численности средневозрастной когорты людей.\n\n2. **Экономические ожидания**: Индекс потребительской уверенности рассчитывается на основе ожиданий изменений личного материального положения и экономической ситуации в стране. Негативные ожидания в этих областях могут также способствовать снижению уверенности.\n\nЭти факторы могут существенно повлиять на потребительские настроения и, как следствие, на индекс потребительской уверенности в 2025 году.', retrieved_chunks=[Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.6663535237312317), Chunk(text='Как мы предполагали при анализе результатов предыдущего раунда обследования, позитивная коррекция индекса потребительской уверенности, начавшаяся в I квартале 2019 г., продолжилась во II квартале. Правда, темпы улучшения показателя остались минимальными (по 1 п. п', chunk_id=33, year=2019, distance=0.6791031956672668), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=54, year=2019, distance=0.7181111574172974), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=141, year=2025, distance=0.7181111574172974), Chunk(text='К сожалению, высокая вероятность снижения индекса потребительской уверенности в ближайшие годы из-за демографических невзгод 90-х годов двадцатого столетия, выраженных в серьёзном сокращении рождаемости, и даже из-за «эхо» Великой Отечественной войны. В настоящее время Россия вступила в фазу изменения демографической пирамиды не только в виде сокращения трудоспособного населения, но и сокращения численности средневозрастной когорты людей', chunk_id=113, year=2025, distance=0.7217340469360352)]),
#  RAGAgentAnswer(dataset_row_id='3e59c74d-0186-4e8f-984d-ec95c67c91a8', answer='В 2025 году доля респондентов, отметивших своё текущее материальное положение как "очень хорошее", составила 0,3%.', retrieved_chunks=[Chunk(text='---\n\n  \n*Доля от общего числа респондентов, %*  \n*(данные за второй квартал Росстатом пока не опубликованы)*\n\n### Текущее материальное положение\n- очень хорошее — 0,3%  \n- хорошее — 6,9%  \n- среднее — 63,0%  \n- плохое — 27,3%  \n- очень плохое — 2,3%  \n- затрудняюсь ответить — 0,2%', chunk_id=25, year=2019, distance=0.8493600487709045), Chunk(text='Одновременно с ростом доли респондентов, отметивших «хорошее» и «очень хорошее» текущее материальное положение, в отчётном квартале наблюдалось увеличение числа тех, кто отмечал «плохое» и «очень плохое» материальное состояние (17,3%) (15,8 и 1,5%, соответственно). В I кв. т. г. относительное значение данного показателя составляло (15,7%). Основная доля ответов (69,8%) пришлась на оценку среднего материального состояния.\n\n---\n\n  \n*Доля от общего числа респондентов, %*', chunk_id=120, year=2025, distance=0.9034214615821838), Chunk(text='В частности, об «очень хорошем» и «хорошем» своём материальном положении сообщили в отчётном квартале 12,9% (0,3 и 12,6%, соответственно) участников опроса. Выявленное значение на 1,2 п. п. выше, чем в I кв. т. г. Однако итоговый результат отчётного квартала на 0,8 п. п. хуже, чем среднеквартальный за 2024 г.', chunk_id=119, year=2025, distance=0.9595717191696167), Chunk(text='---\n\n  \n*Доля от общего числа респондентов, %*\n\n- очень хорошее — 0,3%  \n- хорошее — 12,6%  \n- среднее — 69,8%  \n- плохое — 15,8%  \n- очень плохое — 1,5%  \n- затрудняюсь ответить — 0,0%\n\n  \n*Доля от общего числа респондентов, %*\n\n- очень благоприятные — 0,7%  \n- скорее благоприятные — 11,6%  \n- «плюсов» и «минусов» одинаково — 45,6%  \n- скорее неблагоприятные — 12,5%  \n- совсем неблагоприятные — 29,4%  \n- затрудняюсь ответить — 0,3%  \n\n---\n\n  \n*Доля от общего числа респондентов, %*', chunk_id=121, year=2025, distance=0.9985638856887817), Chunk(text='. Здесь, главное, тенденция тренда. В частности, если растёт доля респондентов с благоприятными оценками своего материального состояния (хорошее, очень хорошее) и одновременно растёт доля респондентов с неблагоприятными оценками (плохое и очень плохое), значит есть повод осторожно утверждать о росте дифференциации доходов среди населения и, соответственно, об усилении неравенства в доходах.', chunk_id=125, year=2025, distance=1.0196133852005005)]),
#  RAGAgentAnswer(dataset_row_id='41571902-6e30-4242-b13f-be8b2a321154', answer='В 2025 году смена тренда Индекса потребительских настроений (ИПУ) с негативного на позитивный является крайне редким явлением. Для таких значительных изменений необходимы очевидные экзогенные или эндогенные факторы. Как показывает анализ, серьёзное улучшение поквартальных значений ИПУ обычно происходит в результате роста доходов населения, включая увеличение заработных плат, социальных выплат и других источников доходов.', retrieved_chunks=[Chunk(text='темпы позитивной динамики ИПУ сохранятся, то для выхода индикатора в нейтральную зону понадобится более двух лет.', chunk_id=37, year=2019, distance=0.8712089657783508), Chunk(text='. п. Несмотря на позитивную коррекцию, и сам ИПУ, и его компоненты пока ещё далеки от своих значений, зафиксированных в период заметного снижения пессимизма потребительских настроений в начале 2018 г.', chunk_id=14, year=2019, distance=0.8771793842315674), Chunk(text='. Правда, темпы улучшения показателя остались минимальными (по 1 п. п. за каждый квартал), но после интенсивного ухудшения настроений потребителей во второй половине 2018 г., когда ИПУ в течение двух кварталов снизился с (-8) до (-17%), такая умеренно позитивная тенденция выглядит обнадёживающе, хотя и находится в зоне статистической погрешности.', chunk_id=34, year=2019, distance=0.9002589583396912), Chunk(text='Среди пяти компонент, входящих в структуру сводного ИПУ в отчётном квартале, наблюдалась преимущественно позитивная динамика по сравнению с предыдущим кварталом.', chunk_id=82, year=2025, distance=0.9479381442070007), Chunk(text='негативного на позитивный — крайне редкое явление за всё время наблюдений. Для таких относительно существенных перестроений должны сработать очевидные экзогенные или эндогенные факторы. Как показывает ретроспективный анализ итогов потребительских опросов, серьёзное улучшение поквартальных значений ИПУ в первую очередь происходит в результате роста доходов населения, в т. ч. роста их заработных плат, социальных выплат, предпринимательских доходов и других структурных источников доходов', chunk_id=71, year=2025, distance=0.9560753107070923)]),
#  RAGAgentAnswer(dataset_row_id='7875fe24-23fd-4110-9421-7d7382aad685', answer='На 5 июля 2019 года объём международных резервов России составил 518,3 миллиарда долларов.', retrieved_chunks=[Chunk(text='. Бюджет страны исполняется с профицитом. На достаточно уровне находится объём средств ФНБ. Международные резервы выросли за долгие годы и превышают в июне текущего года отметку в 500 млрд. долларов, составив на 05.07.2019 518,3 млрд. долларов. Долгое время практически не наблюдается повышенной турбулентности на валютном рынке', chunk_id=43, year=2019, distance=0.980114758014679), Chunk(text='Следует обратить внимание, что помимо 61,5 трлн. рублёвых депозитов у российского населения в апреле т. г. было сосредоточено примерно 3 трлн. руб. на валютных счетах (в пересчёте на рубли) и 10,5 трлн. руб. в виде остатков наличных денег на руках. Суммарно это составляет чуть более 75 трлн. руб. или почти два годовых государственных бюджета России. Это самая большая сумма сбережений населения на вкладах и наличных денег на руках за всё время послевоенных наблюдений.\n\n---', chunk_id=94, year=2025, distance=1.0261256694793701), Chunk(text='По данным ЦБ РФ, в апреле т. г. остаток вкладов на рублёвых счетах населения составил 61,5 трлн. руб. Это примерно годовой приход по процентам по вкладам в районе 10', chunk_id=88, year=2025, distance=1.0738681554794312), Chunk(text='✓ **Индекс произошедших изменений в личном материальном положении** в II кв. 2025 г. по сравнению с I кв. 2025 г. возрос на 1 п. п. и составил (-8%);\n\n✓ **Индекс ожидаемых изменений личного материального положения** в отчётном периоде сохранился на уровне предыдущего квартала — (-3%);\n\n✓ **Индекс произошедших изменений в экономике России за последний год** в отчётном квартале вырос на 6 п. п. относительно предыдущего квартала, составив (-10%). Это один из лучших результатов с 2018 г.;', chunk_id=83, year=2025, distance=1.124166488647461), Chunk(text='результатом в интервале от +0,8 до +1,1%. Дополнительным драйвером роста реальных располагаемых денежных доходов населения в текущем году может стать замедление роста потребительского кредитования, которое с апреля производит постепенное снижение по ставкам. В случае если ЦБ РФ по отношению к заёмщикам с 1 октября 2019 г. применит дополнительные меры по ограничению кредитования, то в прошлом году — примерно 0%', chunk_id=50, year=2019, distance=1.1574950218200684)]),
#  RAGAgentAnswer(dataset_row_id='3ea0a3c1-5d1e-4dde-b1d5-18ff01f77974', answer='В доступных данных нет информации о том, какие конкретно страны в ЕС Россия обгоняла по индексу потребительской уверенности в 2019 году. Если вам нужна дополнительная информация или другие данные, пожалуйста, уточните ваш запрос.', retrieved_chunks=[Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=0.5110183954238892), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=141, year=2025, distance=0.5157114863395691), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=54, year=2019, distance=0.5157114863395691), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.5855765342712402), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=12, year=2019, distance=0.6167984008789062), Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=0.5257964730262756), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=141, year=2025, distance=0.5665968060493469), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=54, year=2019, distance=0.5665968060493469), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.5947263836860657), Chunk(text='Центр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал о потребительских настроениях населения России во II квартале 2019 г. В обзоре использованы итоги опросов потребителей, в которых принимают участие более 5 тыс. человек в возрасте от 16 лет и старше, проживающих в частных домохозяйствах', chunk_id=6, year=2019, distance=0.6446577310562134), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года ...
#  RAGAgentAnswer(dataset_row_id='80821e41-a9f1-4dea-ad07-c210f5986fb1', answer='В 2019 году финансовая ситуация в России была одной из лучших за последние десять лет. Уровень бедности в стране незначительно снижался, а внешнеторговое сальдо и сальдо платежного баланса находились на позитивном стабильном уровне. Также Россия имела одну из самых низких долей государственного внешнего долга в ВВП среди экономик как развитых, так и развивающихся стран. \n\nПрогнозировалось, что к концу 2019 года реальные доходы населения могут перейти в положительную зону благодаря индексации заработных плат бюджетникам и повышению пенсий.', retrieved_chunks=[Chunk(text='. В последнее время, хотя и незначительно, но снижался уровень бедности в стране. На позитивном стабильном уровне находится внешнеторговое сальдо и сальдо платежного баланса, а также уровень мировых цен на основные торгуемые товары российского экспорта. Сегодня в стране наблюдается одна из лучших за последние десять лет финансовая ситуация. Россия в настоящее время имеет одну из самых низких долей государственного внешнего долга в ВВП среди экономик развитых и развивающихся стран', chunk_id=42, year=2019, distance=0.8916279673576355), Chunk(text='✓ **Индекс произошедших изменений в личном материальном положении** в II кв. 2025 г. по сравнению с I кв. 2025 г. возрос на 1 п. п. и составил (-8%);\n\n✓ **Индекс ожидаемых изменений личного материального положения** в отчётном периоде сохранился на уровне предыдущего квартала — (-3%);\n\n✓ **Индекс произошедших изменений в экономике России за последний год** в отчётном квартале вырос на 6 п. п. относительно предыдущего квартала, составив (-10%). Это один из лучших результатов с 2018 г.;', chunk_id=83, year=2025, distance=0.8942574858665466), Chunk(text='. Далее, исходя из объявленной в октябре 2019 г. индексации заработных плат бюджетникам, единовременного ранее повышения пенсий и других индексаций социальных выплат, в конце текущего года можно ожидать перехода реальных доходов в положительную зону, с итоговым', chunk_id=48, year=2019, distance=0.9532710313796997), Chunk(text='Если прогнозировать динамику реальных доходов населения до конца текущего года, исходя из позитивного сценария, то можно с осторожностью предположить, что уже во II квартале 2019 г. мы не увидим такого провала в доходах, как в I квартале (-2,3%), затем по суммарным результатам за девять месяцев текущего года доходы приблизятся к отметке 0%. Далее, исходя из объявленной в октябре 2019 г', chunk_id=47, year=2019, distance=0.9678419232368469), Chunk(text='результатом в интервале от +0,8 до +1,1%. Дополнительным драйвером роста реальных располагаемых денежных доходов населения в текущем году может стать замедление роста потребительского кредитования, которое с апреля производит постепенное снижение по ставкам. В случае если ЦБ РФ по отношению к заёмщикам с 1 октября 2019 г. применит дополнительные меры по ограничению кредитования, то в прошлом году — примерно 0%', chunk_id=50, year=2019, distance=0.9837868213653564)]),
#  RAGAgentAnswer(dataset_row_id='4a0cb62e-599d-447e-be34-13df205b7296', answer='В 2025 году основная часть депозитной базы формируется верхней пятой (с половиной доходов) двадцатипроцентной группы населения, которая концентрирует около половины всех доходов населения (46,2%). Эта группа является основным держателем депозитов на банковских счетах и, соответственно, получает значительные доходы от собственности.', retrieved_chunks=[Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=1.1160962581634521), Chunk(text='Следует обратить внимание, что помимо 61,5 трлн. рублёвых депозитов у российского населения в апреле т. г. было сосредоточено примерно 3 трлн. руб. на валютных счетах (в пересчёте на рубли) и 10,5 трлн. руб. в виде остатков наличных денег на руках. Суммарно это составляет чуть более 75 трлн. руб. или почти два годовых государственных бюджета России. Это самая большая сумма сбережений населения на вкладах и наличных денег на руках за всё время послевоенных наблюдений.\n\n---', chunk_id=94, year=2025, distance=1.2992035150527954), Chunk(text='---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.\n\nЦентр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал «Потребительские настроения населения во II квартале 2025 г.», подготовленный в рамках Программы фундаментальных исследований НИУ ВШЭ.', chunk_id=57, year=2025, distance=1.30007004737854), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=1.3112246990203857), Chunk(text='. Учитывая, что, по данным Росстата, верхняя пятая (с половиной доходов) двадцатипроцентная группа населения концентрирует у себя около половины всех доходов населения (46,2%), можно предположить, что именно эта группа является основным держателем депозитов на банковских счетах, и, соответственно, они же являются преимущественными получателями доходов от собственности.', chunk_id=90, year=2025, distance=1.3171567916870117)]),
# ...
#  RAGAgentAnswer(dataset_row_id='f7dd89b2-b379-4875-8916-bfbab9dcaefd', answer='В 2025 году только 0,4% респондентов считали условия для крупных покупок очень благоприятными.', retrieved_chunks=[Chunk(text='### Ожидаемое изменение цен\n- значительно снизятся — 0,1%  \n- незначительно снизятся — 1,7%  \n- останутся на прежнем уровне — 1,5%  \n- незначительно возрастут — 40,0%  \n- значительно возрастут — 50,2%  \n- затрудняюсь ответить — 0,2%  \n\n### Условия для крупных покупок\n- очень благоприятные — 0,4%  \n- скорее благоприятные — 9,2%  \n- «плюсов» и «минусов» одинаково — 38,0%  \n- скорее неблагоприятные — 16,9%  \n- совсем неблагоприятные — 33,2%  \n- затрудняюсь ответить — 1,7%', chunk_id=26, year=2019, distance=0.974597692489624), Chunk(text='✓ **Индекс ожидаемых изменений экономической ситуации в стране** в анализируемом периоде вырос на 4 п. п., достигнув нейтрального значения — (0%);\n\n✓ **Индекс благоприятности условий для крупных покупок** вырос на 1 п. п., составив (-21%).\n\n---\n\n  \n*Баланс, %*\n\n---', chunk_id=84, year=2025, distance=1.1286871433258057), Chunk(text='---\n\nПятый компонент ИПУ, частный индекс **благоприятности условий для крупных покупок**, увеличился относительно предыдущего квартала на 3 п. п. Индекс **благоприятности условий для сбережений** (согласно принятой методологии в состав ИПУ не включается) также улучшился, но лишь на 1 п. п.\n\n---\n\n  \n*Балансы, %*\n\n- благоприятность условий для крупных покупок  \n- благоприятность условий для сбережений  \n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=16, year=2019, distance=1.130640983581543), Chunk(text='### Условия для формирования сбережений\n- очень благоприятные — 0,3%  \n- скорее благоприятные — 7,3%  \n- «плюсов» и «минусов» одинаково — 31,1%  \n- скорее неблагоприятные — 21,8%  \n- совсем неблагоприятные — 38,0%  \n- затрудняюсь ответить — 1,7%  \n\n---', chunk_id=27, year=2019, distance=1.1645050048828125), Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=1.1701264381408691)]),
#  RAGAgentAnswer(dataset_row_id='17fc34cc-b8eb-49f0-b384-1d1db1998846', answer='В 2025 году процент респондентов, затруднявшихся ответить на вопрос об условиях для крупных покупок, составил 1,7%.', retrieved_chunks=[Chunk(text='. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% респондентов.', chunk_id=29, year=2019, distance=0.846405029296875), Chunk(text='## Распределение ответов на отдельные вопросы анкеты\n\nАнализ распределения мнений респондентов относительно их личного материального положения, условий для крупных покупок и сбережений, а также ожидаемой в следующем году инфляции позволяет более детально изучить эти аспекты формирования потребительской уверенности, в значительной степени определяющие состояние платежеспособного спроса на товары и услуги со стороны населения.\n\n---', chunk_id=24, year=2019, distance=0.9197995662689209), Chunk(text='### Ожидаемое изменение цен\n- значительно снизятся — 0,1%  \n- незначительно снизятся — 1,7%  \n- останутся на прежнем уровне — 1,5%  \n- незначительно возрастут — 40,0%  \n- значительно возрастут — 50,2%  \n- затрудняюсь ответить — 0,2%  \n\n### Условия для крупных покупок\n- очень благоприятные — 0,4%  \n- скорее благоприятные — 9,2%  \n- «плюсов» и «минусов» одинаково — 38,0%  \n- скорее неблагоприятные — 16,9%  \n- совсем неблагоприятные — 33,2%  \n- затрудняюсь ответить — 1,7%', chunk_id=26, year=2019, distance=0.9693882465362549), Chunk(text='Так, исходя из обобщённых мнений респондентов, в отчётном квартале лишь 2,2% из них надеются на снижение цен в течение ближайшего года (0,3% — значительного и 1,9% — незначительного). Об ожидаемом росте цен в своих ответах констатировало подавляющее большинство участников опроса (86%). Чуть более 10% респондентов (11,8%) надеются на сохранение текущих цен на товары и услуги в интервале ближайшего года.\n## Методологические примечания', chunk_id=138, year=2025, distance=1.0052645206451416), Chunk(text='Весьма редко участники опроса определённо позитивно оценивали своё личное материальное положение, сложившиеся условия для совершения крупных покупок и формирования сбережений: доля «очень благоприятных» оценок этих показателей не превышала 0,3–0,4%. Умеренно позитивного мнения придерживался лишь один из десяти респондентов, превалировали нейтральные и умеренно негативные настроения. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов)', chunk_id=28, year=2019, distance=1.0103029012680054)]),
#  RAGAgentAnswer(dataset_row_id='60a79f64-8f20-44dc-955e-8e8deee332e8', answer='Обобщающий индекс потребительской уверенности в 2025 году рассчитывается как среднее арифметическое пяти частных индексов, которые включают:\n\n1. Произошедшие изменения личного материального положения.\n2. Ожидаемые изменения личного материального положения.\n3. Произошедшие изменения экономической ситуации в России.\n4. Ожидаемые изменения экономической ситуации в России.\n5. Благоприятность условий для крупных покупок.\n\nЭта информация представлена в методологических примечаниях отчета за 2025 год.', retrieved_chunks=[Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=141, year=2025, distance=0.6015862822532654), Chunk(text='Обобщающий индекс потребительской уверенности рассчитывается как среднее арифметическое пяти частных индексов: произошедших и ожидаемых изменений личного материального положения, произошедших и ожидаемых изменений экономической ситуации в России, благоприятности условий для крупных покупок.', chunk_id=54, year=2019, distance=0.6015862822532654), Chunk(text='## Потребительские настроения населения во II квартале 2019 года\n\n## Индекс потребительской уверенности по различным возрастным категориям', chunk_id=17, year=2019, distance=0.6140711307525635), Chunk(text='---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.\n\nЦентр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал «Потребительские настроения населения во II квартале 2025 г.», подготовленный в рамках Программы фундаментальных исследований НИУ ВШЭ.', chunk_id=57, year=2025, distance=0.6730295419692993), Chunk(text='---\n\n## Индекс потребительской уверенности\n\n  \n*Баланс, %*\n\n(Примечание: серая линия обозначает среднее долговременное значение ИПУ за весь период наблюдений (с 1992 г.).)\n\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=12, year=2019, distance=0.6904019117355347)]),
#  RAGAgentAnswer(dataset_row_id='f5995543-80ec-4eb6-a0e2-fdf0b5d0de05', answer='В 2025 году важнейшим конъюнктурным фактором для формирования стратегического плана экономического и потребительского поведения является индекс потребительской уверенности. Этот индекс является ключевым компонентом сводного индекса экономического настроения, который характеризует состояние делового климата в экономике страны.', retrieved_chunks=[Chunk(text='# ПОТРЕБИТЕЛЬСКИЕ НАСТРОЕНИЯ НАСЕЛЕНИЯ  \n## ВО II КВАРТАЛЕ 2025 г.\n\n---\n\nИнститут статистических исследований  \nи экономики знаний  \n\nЦентр конъюнктурных исследований  \n\n---\n\nИюль ‘25  \nМосква\n\n**Авторы:**  \nОстанкович Г.В., Лола И.С., Асосков Д.Г., Усов Н.А.\n\n---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.', chunk_id=56, year=2025, distance=1.0137646198272705), Chunk(text='---\n\n## Основные итоги II квартала 2025 г.', chunk_id=64, year=2025, distance=1.1239092350006104), Chunk(text='---\n\n**Потребительские настроения населения во II квартале 2025 г.** – М.: НИУ ВШЭ, 2025. – 13 с.\n\nЦентр конъюнктурных исследований Института статистических исследований и экономики знаний НИУ ВШЭ представляет информационно-аналитический материал «Потребительские настроения населения во II квартале 2025 г.», подготовленный в рамках Программы фундаментальных исследований НИУ ВШЭ.', chunk_id=57, year=2025, distance=1.1410993337631226), Chunk(text='Основные требования ко всем композитным индикаторам конъюнктурных обследований в сфере услуг – это измерение многомерных понятий; наличие отражающих свойств по выпуску результатов обследований; прозрачность метода агрегации; простота интерпретации и доступность для эффективного восприятия.\n\n---\n\n*Материал подготовлен в ходе проведения исследования в рамках Программы фундаментальных исследований Национального исследовательского университета «Высшая школа экономики» (НИУ ВШЭ).*\n\n---', chunk_id=61, year=2025, distance=1.2598695755004883), Chunk(text='Индекс потребительской уверенности Росстата является важнейшей компонентой сводного индекса экономического настроения (ИЭН ВШЭ), который ежеквартально рассчитывается Центром конъюнктурных исследований и интегрально характеризует состояние делового климата в экономике страны.\n\n---\n\n## Основные итоги II квартала 2019 года', chunk_id=8, year=2019, distance=1.2851824760437012)]),
#  RAGAgentAnswer(dataset_row_id='635706a4-8be4-4550-9782-02bbaf29e2cd', answer='В 2019 году восприятие респондентов относительно неблагоприятных условий для крупных покупок изменилось следующим образом:\n\n1. В I квартале 2019 года 17% респондентов сообщили о "совсем неблагоприятных" условиях для крупных покупок и сбережений.\n2. Во II квартале 2019 года доля "неблагоприятных" оценок условий для крупных покупок выросла с 4,5% до 50%, а для сбережений — с 5,7% до 60%. Это свидетельствует о значительном ухудшении восприятия условий по сравнению с предыдущим кварталом.\n3. Также увеличилась доля участников опроса, характеризующих собственное материальное положение как "плохое" или "очень плохое" — с 26% до 30%.\n\nТаким образом, в 2019 году наблюдалось резкое ухудшение восприятия респондентами условий для крупных покупок.', retrieved_chunks=[Chunk(text='. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов). О «совсем неблагоприятных» условиях для крупных покупок и сбережений в I квартале 2019 г. сообщили 17 и 22% респондентов.', chunk_id=29, year=2019, distance=0.6096226572990417), Chunk(text='Распределение мнений респондентов сместилось в негативную сторону относительно предыдущего квартала. В частности, доля «неблагоприятных» оценок условий для крупных покупок и сбережений выросла с 4,5 до 50% и с 5,7 до 60% соответственно при некотором снижении доли «благоприятных» оценок. Аналогично, с 26 до 30% выросла доля участников опроса, характеризующих собственное материальное положение как «плохое» или «очень плохое».\n## Потребительские настроения населения во II квартале 2019 года', chunk_id=30, year=2019, distance=0.6936779618263245), Chunk(text='Весьма редко участники опроса определённо позитивно оценивали своё личное материальное положение, сложившиеся условия для совершения крупных покупок и формирования сбережений: доля «очень благоприятных» оценок этих показателей не превышала 0,3–0,4%. Умеренно позитивного мнения придерживался лишь один из десяти респондентов, превалировали нейтральные и умеренно негативные настроения. «Очень плохое» личное финансовое положение также отмечалось лишь изредка (2% ответов)', chunk_id=28, year=2019, distance=0.7888715863227844), Chunk(text='## Потребительские настроения населения во II квартале 2019 года', chunk_id=49, year=2019, distance=0.8185028433799744), Chunk(text='- **Индекс потребительской уверенности (ИПУ)** повысился на 1 процентный пункт (п. п.) до значения (-15%);\n- **Улучшение личного материального положения за последние 12 месяцев** констатировали 11% респондентов, а его ухудшение — 32% (кварталом ранее — 10 и 36%);\n- **Ухудшение личного материального положения в течение следующих 12 месяцев** ожидают 19% респондентов (кварталом ранее — 23%);', chunk_id=9, year=2019, distance=0.9044157266616821)]),
#  RAGAgentAnswer(dataset_row_id='0ea06009-054d-427e-bd67-40579b294330', answer='В 2025 году инфляция у низкодоходного населения, которое не имеет возможности формировать банковские сбережения, как правило, на несколько процентов выше, чем у высокодоходного населения. Это связано с тем, что низкодоходные группы не могут "отбивать" рост цен на товары и услуги полученными процентами по депозитам. \n\nК сожалению, конкретные цифры о том, какая часть населения сталкивается с более высокой инфляцией из-за невозможности формировать банковские сбережения, в доступных данных не указаны.', retrieved_chunks=[Chunk(text='Естественно, получатели процентного по депозитам могут этими финансовыми ресурсами минимизировать инфляционное давление, тратя полученные от процентов по депозитам практически «безболезненные деньги» на частичное погашение роста цен на товары и услуги. Именно этот механизм высокодоходного населения, имеющего депозитную базу, объясняет потребляемый «слой», что инфляция — это «налог на бедных», т. е', chunk_id=91, year=2025, distance=1.0240890979766846), Chunk(text='. применит дополнительные меры по ограничению кредитования, то в прошлом году — примерно 0%. Далее, если будет сохранена относительно стабильная ситуация на валютном рынке, не будет резких колебаний курса рубля и значительных скачков цен на основные товары российского экспорта, последующего падения курса рубля и роста уровня инфляции — не рассматривается в виде крайне маловероятности данных событий.', chunk_id=51, year=2019, distance=1.0356563329696655), Chunk(text='. е. на людей, не имеющих возможности в достаточном объёме формировать свои банковские сбережения и «отбивать» полученными процентами рост цен. Исходя из изложенного, инфляция у низкодоходного населения, как правило, на несколько процентов выше, чем у высокодоходного населения. Вдобавок, у низкодоходного населения в структуре потребления всегда заметно выше доля затрат на «продовольственные товары», чем у высокодоходного', chunk_id=92, year=2025, distance=1.124419093132019), Chunk(text='. Бюджет страны исполняется с профицитом. На достаточно уровне находится объём средств ФНБ. Международные резервы выросли за долгие годы и превышают в июне текущего года отметку в 500 млрд. долларов, составив на 05.07.2019 518,3 млрд. долларов. Долгое время практически не наблюдается повышенной турбулентности на валютном рынке', chunk_id=43, year=2019, distance=1.1756242513656616), Chunk(text='### Условия для формирования сбережений\n- очень благоприятные — 0,3%  \n- скорее благоприятные — 7,3%  \n- «плюсов» и «минусов» одинаково — 31,1%  \n- скорее неблагоприятные — 21,8%  \n- совсем неблагоприятные — 38,0%  \n- затрудняюсь ответить — 1,7%  \n\n---', chunk_id=27, year=2019, distance=1.1787407398223877)])]

# %%
from evaluation import evaluate

df_metrics = evaluate(
    answers=results,
    dataset=df_test,
    client=client,
    model=MODEL,
    overlap_threshold=0.3,
    compute_faithfulness=True,
)

print(f"\u2705 Оценка завершена: {df_metrics.shape[0]} строк, {df_metrics.shape[1]} колонок")
df_metrics.head(10)
# Out:
# Retrieval metrics: 100%|██████████| 150/150 [00:00<00:00, 3488.74it/s]
# Faithfulness (RAGAS): 100%|██████████| 150/150 [10:46<00:00,  4.31s/it]
# ✅ Оценка завершена: 150 строк, 9 колонок
#                                      id  \
# 0  e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1  c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2  7e727f79-c6ff-4ff0-b101-bcec2b0f7260
# 3  d52e6df3-d5ad-404e-9da9-f6f1855d16df
# 4  536bf426-d85f-472c-b434-6796078cf647
# 5  e3453b4c-2d2a-4569-899d-f731158e2d36
# 6  a3ae1b1c-a296-4e85-b8df-6ca1ed2093d0
# 7  25a2eff0-2893-471f-a145-20aa63633e13
# 8  49287b9e-2dad-4902-a389-bc0a34494dfc
# 9  6192474e-db88-47a1-9c27-5c5e89d5e430
#
#                                             question  precision  recall  \
# 0  В 2019 году как изменился индекс потребительск...        0.2     1.0
# 1  Согласно данным 2025 года, какой фактор являет...        0.2     1.0
# 2  Согласно данным 2019 года, что является основн...        0.2     1.0
# 3  Какой процент респондентов в 2025 году затрудн...        0.0     0.0
# 4  Согласно данным 2019 года, какой был баланс от...        0.2     1.0
# 5  Согласно данным 2025 года, какие социальные по...        0.2     1.0
# 6  В 2025 году какова связь между потребительским...        0.2     1.0
# 7  В 2019 году какое место в рейтинге стран ЕС по...        0.0     0.0
# 8  Какая доля населения в 2025 году в основном фо...        0.0     0.0
# 9  Какой процент респондентов оказался в затрудни...        0.2     1.0
#
#          f1       mrr       map      ndcg  faithfulness
# 0  0.333333  0.333333  0.333333  0.500000          1.00
# 1  0.333333  1.000000  1.000000  1.000000          1.00
# 2  0.333333  1.000000  1.000000  1.000000          1.00
# 3  0.000000  0.000000  0.000000  0.000000          0.50
# 4  0.333333  1.000000  1.000000  1.000000          1.00
# 5  0.333333  0.333333  0.333333  0.500000          1.00
# 6  0.333333  0.500000  0.500000  0.630930          0.40
# 7  0.000000  0.000000  0.000000  0.000000          0.00
# 8  0.000000  0.000000  0.000000  0.000000          0.75
# 9  0.333333  0.250000  0.250000  0.430677          0.00

# %% [markdown]
# ---
# ## 5. Анализ результатов

# %%
metric_cols = ["precision", "recall", "f1", "mrr", "map", "ndcg", "faithfulness"]
display_names = ["Precision@K", "Recall@K", "F1@K", "MRR", "MAP", "NDCG@K", "Faithfulness"]

summary = df_metrics[metric_cols].mean()
summary.index = display_names

print("=" * 45)
print("  ИТОГОВЫЕ МЕТРИКИ КАЧЕСТВА RAG-АГЕНТА")
print("=" * 45)
for name, val in summary.items():
    bar = "\u2588" * int(val * 30) + "\u2591" * (30 - int(val * 30))
    print(f"  {name:<15} {val:.4f}  {bar}")
print("=" * 45)
# Out:
# =============================================
#   ИТОГОВЫЕ МЕТРИКИ КАЧЕСТВА RAG-АГЕНТА
# =============================================
#   Precision@K     0.1447  ████░░░░░░░░░░░░░░░░░░░░░░░░░░
#   Recall@K        0.7222  █████████████████████░░░░░░░░░
#   F1@K            0.2395  ███████░░░░░░░░░░░░░░░░░░░░░░░
#   MRR             0.4968  ██████████████░░░░░░░░░░░░░░░░
#   MAP             0.4884  ██████████████░░░░░░░░░░░░░░░░
#   NDCG@K          0.5484  ████████████████░░░░░░░░░░░░░░
#   Faithfulness    0.6303  ██████████████████░░░░░░░░░░░░
# =============================================

# %%
# Сводная таблица
df_summary = pd.DataFrame(
    list(zip(display_names, summary.values)),
    columns=["Метрика", "Значение"],
)
df_summary["Значение"] = df_summary["Значение"].round(4)
df_summary
# Out:
#         Метрика  Значение
# 0   Precision@K    0.1447
# 1      Recall@K    0.7222
# 2          F1@K    0.2395
# 3           MRR    0.4968
# 4           MAP    0.4884
# 5        NDCG@K    0.5484
# 6  Faithfulness    0.6303

# %%
# Распределение метрик
df_metrics[metric_cols].describe().round(4)
# Out:
#        precision    recall        f1       mrr       map      ndcg  \
# count   150.0000  150.0000  150.0000  150.0000  150.0000  150.0000
# mean      0.1447    0.7222    0.2395    0.4968    0.4884    0.5484
# std       0.0869    0.4351    0.1436    0.4228    0.4251    0.4030
# min       0.0000    0.0000    0.0000    0.0000    0.0000    0.0000
# 25%       0.0667    0.3333    0.1127    0.1039    0.0460    0.1591
# 50%       0.2000    1.0000    0.3333    0.3333    0.3333    0.5000
# 75%       0.2000    1.0000    0.3333    1.0000    1.0000    1.0000
# max       0.2000    1.0000    0.3333    1.0000    1.0000    1.0000
#
#        faithfulness
# count      150.0000
# mean         0.6303
# std          0.3691
# min          0.0000
# 25%          0.4071
# 50%          0.7321
# 75%          1.0000
# max          1.0000

# %%
# Худшие вопросы по F1
worst = df_metrics.nsmallest(5, "f1")[["id", "question", "precision", "recall", "f1", "faithfulness"]]
worst
# Out:
#                                       id  \
# 3   d52e6df3-d5ad-404e-9da9-f6f1855d16df
# 7   25a2eff0-2893-471f-a145-20aa63633e13
# 8   49287b9e-2dad-4902-a389-bc0a34494dfc
# 16  3ea0a3c1-5d1e-4dde-b1d5-18ff01f77974
# 17  80821e41-a9f1-4dea-ad07-c210f5986fb1
#
#                                              question  precision  recall   f1  \
# 3   Какой процент респондентов в 2025 году затрудн...        0.0     0.0  0.0
# 7   В 2019 году какое место в рейтинге стран ЕС по...        0.0     0.0  0.0
# 8   Какая доля населения в 2025 году в основном фо...        0.0     0.0  0.0
# 16  В 2019 году какие страны в ЕС Россия обгоняла ...        0.0     0.0  0.0
# 17  Согласно данным 2019 года, каково было состоян...        0.0     0.0  0.0
#
#     faithfulness
# 3          0.500
# 7          0.000
# 8          0.750
# 16         0.000
# 17         0.875

# %%
# Лучшие вопросы по F1
best = df_metrics.nlargest(5, "f1")[["id", "question", "precision", "recall", "f1", "faithfulness"]]
best
# Out:
#                                      id  \
# 0  e876ec3b-7442-4145-99d0-d6bb85fd982d
# 1  c7304cf4-9ebf-461b-acce-4dc987c21bcc
# 2  7e727f79-c6ff-4ff0-b101-bcec2b0f7260
# 4  536bf426-d85f-472c-b434-6796078cf647
# 5  e3453b4c-2d2a-4569-899d-f731158e2d36
#
#                                             question  precision  recall  \
# 0  В 2019 году как изменился индекс потребительск...        0.2     1.0
# 1  Согласно данным 2025 года, какой фактор являет...        0.2     1.0
# 2  Согласно данным 2019 года, что является основн...        0.2     1.0
# 4  Согласно данным 2019 года, какой был баланс от...        0.2     1.0
# 5  Согласно данным 2025 года, какие социальные по...        0.2     1.0
#
#          f1  faithfulness
# 0  0.333333           1.0
# 1  0.333333           1.0
# 2  0.333333           1.0
# 4  0.333333           1.0
# 5  0.333333           1.0
